# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\manas\anaconda3\lib\site-packages (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (15.0.6.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (23.3.3)
# Requirement already satisfied: numpy>=1.20 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.7.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.51.3)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.2.0)
# Requirement already satisfied: packaging in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (22.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.14.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.4.0)
# Requirement already satisfied: setuptools in c:\users\manas\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\manas\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.16.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\manas\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\manas\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\manas\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\manas\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\manas\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\manas\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.11.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\manas\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\manas\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\manas\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\manas\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\manas\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\manas\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\manas\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\manas\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import time
import math
from tqdm import tqdm_notebook as tqdm
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use(['classic'])
# %matplotlib inline
import cProfile as cProfile
from memory_profiler import profile
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

len_train, len_test = len(x_train), len(x_test)
y_train = y_train.astype('int64').reshape(len_train)
y_test = y_test.astype('int64').reshape(len_test)

train_mean = np.mean(x_train, axis=(0,1,2))
train_std = np.std(x_train, axis=(0,1,2))

# Doing Image Normalization
normalize = lambda x: ((x - train_mean) / train_std).astype('float32') 
# Padding added to do random crop even at image border 
pad4 = lambda x: np.pad(x, [(0, 0), (4, 4), (4, 4), (0, 0)], mode='reflect')

x_train = normalize(pad4(x_train))
# Augmentation in test data is being avoided
x_test = normalize(x_test)

# Defining batch size, number of epochs and other parameters
BATCH_SIZE = 32 
MOMENTUM = 0.9 
LEARNING_RATE = 0.4 
WEIGHT_DECAY = 5e-4 
EPOCHS = 3 

# Defining data augmentation function
def data_aug(image, label):
    # Performing data augmentation 
    return image, label

# Creating train and test datasets
train_set = tf.data.Dataset.from_tensor_slices((x_train, y_train)).map(data_aug,num_parallel_calls=tf.data.experimental.AUTOTUNE).shuffle(len(x_train)).batch(BATCH_SIZE).prefetch(1)
test_set = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH_SIZE)

# %%
(x_train.shape, y_train.shape), (x_test.shape, y_test.shape)
# Out:
# (((50000, 40, 40, 3), (50000,)), ((10000, 32, 32, 3), (10000,)))

# %%
data_aug = lambda x, y: (tf.image.random_flip_left_right(tf.image.random_crop(x, [32, 32, 3])), y)

# %%
# Using Kaiming He Initialization for kernel initialization

def init_kaiming_he(shape, dtype=tf.float32, partition_info=None):

  fan = np.prod(shape[:-1])

  bound = 1 / math.sqrt(fan)

  return tf.random.uniform(shape, minval=-bound, maxval=bound, dtype=dtype)

# %%
# Creating model using subclassing API 
# Same can be achieved using Functional API or Sequential API

class ConvBN(tf.keras.Model):

  def __init__(self, c_out):

    super().__init__()

    self.conv = tf.keras.layers.Conv2D(filters=c_out, kernel_size=3, padding="SAME", kernel_initializer=init_kaiming_he, use_bias=False)

    self.bn = tf.keras.layers.BatchNormalization(momentum=0.9, epsilon=1e-5)


  def call(self, inputs):

    return tf.nn.relu(self.bn(self.conv(inputs)))

# %%
class ResBlk(tf.keras.Model):

  def __init__(self, c_out, pool, res = False):

    super().__init__()

    self.conv_bn = ConvBN(c_out)

    self.pool = pool

    self.res = res

    if self.res:

      self.res1 = ConvBN(c_out)

      self.res2 = ConvBN(c_out)

      

  def call(self, inputs):

    h = self.pool(self.conv_bn(inputs))

    if self.res:

      h = h + self.res2(self.res1(h))

    return h

# %%
class CIFAR10AutoGrad(tf.keras.Model):

  def __init__(self, c=64, weight=0.125):

    super().__init__()

    self.maxpool = tf.keras.layers.MaxPooling2D()

    self.init_conv_bn = ConvBN(c)

    self.blk1 = ResBlk(c*3, self.maxpool, res = True)

    self.blk2 = ResBlk(c*6, self.maxpool)

    self.blk3 = ResBlk(c*9, self.maxpool, res = True)

    self.pool = tf.keras.layers.GlobalMaxPool2D()

    self.linear = tf.keras.layers.Dense(10, kernel_initializer=init_kaiming_he, use_bias=False)

    self.weight = weight

# Building the model

  def call(self, x, y):

    h = self.pool(self.maxpool(self.blk3(self.blk2(self.blk1(self.init_conv_bn(x))))))

    h = self.linear(h) * self.weight

    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=h, labels=y) 

    loss = tf.reduce_sum(ce)

    correct = tf.reduce_sum(tf.cast(tf.math.equal(tf.argmax(h, axis = 1), y), tf.float32))

    return loss, correct

# %%
# Creating instance of CIFAR10AutoGrad class 
model =CIFAR10AutoGrad()
batches_per_epoch = len_train//BATCH_SIZE + 1

lr_schedule = lambda t: np.interp([t], [0, (EPOCHS+1)//5, EPOCHS], [0, LEARNING_RATE, 0])[0]
global_step = tf.Variable(0, name='global_step',trainable=False) #global_step is defined as the number of batches that have been seen by the graph. Each time a batch is provided, the weights are updated in such a direction that it will minimize the loss . Moreover, global_step tracks the number of batches meet so far and when it is passed to the minimize() argument list, it increases by one.
lr_func = lambda: lr_schedule(global_step/batches_per_epoch)/BATCH_SIZE
opt = tf.optimizers.SGD(lr_func, momentum=MOMENTUM, nesterov=True)# # Instantiate an optimizer.
# Add data augmentation
data_aug = lambda x, y: (tf.image.random_flip_left_right(tf.image.random_crop(x, [32, 32, 3])), y)

# %%
t = time.time()

@profile
def fit():

  # Creating batches for test data

  test_set = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH_SIZE)

  train_set = tf.data.Dataset.from_tensor_slices((x_train, y_train)).map(data_aug,num_parallel_calls=tf.data.experimental.AUTOTUNE).shuffle(len_train).batch(BATCH_SIZE).prefetch(1)

  #summary_writer = tf.summary.create_file_writer('./log/{}'.format(dt.datetime.now().strftime("%Y-%m-%d-%H-%M-%S")))

  train_summary_writer = tf.summary.create_file_writer('./logs/train')

  test_summary_writer = tf.summary.create_file_writer('./logs/test')    


  for epoch in range(EPOCHS):

    train_loss = test_loss = train_acc = test_acc = 0.0

    with train_summary_writer.as_default():

      tf.summary.trace_on(graph=True, profiler=True) # To start capturing profiler in Tensorboard

      tf.keras.backend.set_learning_phase(1)

      for (x, y) in tqdm(train_set): # Iterating over the batches of train dataset objects .

        with tf.GradientTape() as tape:

          loss, correct = model(x, y)

          var = model.trainable_variables

          grads = tape.gradient(loss, var)

          opt.apply_gradients(zip(grads, var))

          global_step.assign_add(1)

        # Adding extra losses created during this forward pass

        train_loss += loss.numpy()

        train_acc += correct.numpy()


      tf.summary.scalar('train loss', train_loss/len_train, step=epoch)

      tf.summary.scalar('train acc', (train_acc/len_train)*100, step=epoch)

      tf.summary.trace_export(name="Train", step=epoch,profiler_outdir='./logs/train/trace') # Close Profiling when we do export

      tf.keras.backend.set_learning_phase(0)

      

    with test_summary_writer.as_default(): 

      tf.summary.trace_on(graph=True, profiler=True)

      for (x, y) in test_set:#  Iterating over the batches of train dataset objects .


        loss, correct = model(x, y)

        test_loss += loss.numpy()

        test_acc += correct.numpy()         

      tf.summary.scalar('test loss', test_loss/len_test, step=epoch)

      tf.summary.scalar('test acc', (test_acc/len_test)*100, step=epoch) 

      tf.summary.trace_export(name="Test", step=epoch,profiler_outdir='./logs/test/trace')  


      template = 'Epoch {}, lr:{:.3f},Train Loss: {:.3f},Train Accuracy: {:.3f}, Test Loss: {:.3f}, Test Accuracy: {:.3f},Time Taken: {:.2f}'

      print (template.format(epoch+1,lr_schedule(epoch+1),train_loss/len_train,(train_acc/len_train)*100,test_loss/len_test,(test_acc/len_test)*100,time.time() - t))

# %%
if __name__ == '__main__':
 cProfile.runctx('print (fit())', globals(),locals(),"./logs/cifar10.prof")
# Out:
# ERROR: Could not find file C:\Users\MANAS\AppData\Local\Temp\ipykernel_8228\1201675695.py
# WARNING:tensorflow:From C:\Users\MANAS\anaconda3\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From C:\Users\MANAS\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1332: start (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.start` instead.
#   0%|          | 0/1563 [00:00<?, ?it/s]
# WARNING:tensorflow:From C:\Users\MANAS\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1383: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:From C:\Users\MANAS\anaconda3\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1383: save (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# `tf.python.eager.profiler` has deprecated, use `tf.profiler` instead.
# WARNING:tensorflow:From C:\Users\MANAS\anaconda3\lib\site-packages\tensorflow\python\eager\profiler.py:150: maybe_create_event_file (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# `tf.python.eager.profiler` has deprecated, use `tf.profiler` instead.
# Epoch 1, lr:0.267,Train Loss: 1.626,Train Accuracy: 41.674, Test Loss: 1.252, Test Accuracy: 55.730,Time Taken: 2102.72
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 2, lr:0.133,Train Loss: 0.975,Train Accuracy: 65.854, Test Loss: 0.843, Test Accuracy: 70.090,Time Taken: 5128.50
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 3, lr:0.000,Train Loss: 0.769,Train Accuracy: 73.502, Test Loss: 0.789, Test Accuracy: 74.820,Time Taken: 7819.84
# None

# %%
model.summary()
# Out:
# Model: "cifar10_auto_grad"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  max_pooling2d (MaxPooling2D  multiple                 0
#  )
#
#  conv_bn (ConvBN)            multiple                  1984
#
#  res_blk (ResBlk)            multiple                  776448
#
#  res_blk_1 (ResBlk)          multiple                  665088
#
#  res_blk_2 (ResBlk)          multiple                  7969536
#
#  global_max_pooling2d (Globa  multiple                 0
#  lMaxPooling2D)
#
#  dense (Dense)               multiple                  5760
#
# =================================================================
# Total params: 9,418,816
# Trainable params: 9,413,312
# Non-trainable params: 5,504
# _________________________________________________________________

# %%
# !pip install jupyter_tensorboard
# %load_ext tensorboard
# Out:
# Requirement already satisfied: jupyter_tensorboard in c:\users\manas\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: notebook>=5.0 in c:\users\manas\anaconda3\lib\site-packages (from jupyter_tensorboard) (6.5.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (0.5.2)
# Requirement already satisfied: prometheus-client in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (0.14.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (5.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (1.5.6)
# Requirement already satisfied: traitlets>=4.2.1 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (5.7.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (6.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (1.8.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (7.3.4)
# Requirement already satisfied: ipython-genutils in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (23.2.0)
# Requirement already satisfied: nbformat in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (5.7.0)
# Requirement already satisfied: argon2-cffi in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (3.1.2)
# Requirement already satisfied: ipykernel in c:\users\manas\anaconda3\lib\site-packages (from notebook>=5.0->jupyter_tensorboard) (6.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manas\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.0->jupyter_tensorboard) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\manas\anaconda3\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.0->jupyter_tensorboard) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\manas\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.0->jupyter_tensorboard) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\manas\anaconda3\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.0->jupyter_tensorboard) (305.1)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\manas\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\manas\anaconda3\lib\site-packages (from nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (2.1.1)
# Requirement already satisfied: lxml in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (4.9.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (0.5.13)
# Requirement already satisfied: bleach in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (0.1.2)
# Requirement already satisfied: defusedxml in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (0.7.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (2.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (4.11.1)
# Requirement already satisfied: packaging in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (22.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (0.8.4)
# Requirement already satisfied: tinycss2 in c:\users\manas\anaconda3\lib\site-packages (from nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\manas\anaconda3\lib\site-packages (from nbformat->notebook>=5.0->jupyter_tensorboard) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\manas\anaconda3\lib\site-packages (from nbformat->notebook>=5.0->jupyter_tensorboard) (4.17.3)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\manas\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=5.0->jupyter_tensorboard) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\manas\anaconda3\lib\site-packages (from argon2-cffi->notebook>=5.0->jupyter_tensorboard) (21.2.0)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\manas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.0->jupyter_tensorboard) (8.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\manas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.0->jupyter_tensorboard) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\manas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.0->jupyter_tensorboard) (1.5.1)
# Requirement already satisfied: psutil in c:\users\manas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.0->jupyter_tensorboard) (5.9.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\manas\anaconda3\lib\site-packages (from ipykernel->notebook>=5.0->jupyter_tensorboard) (0.1.2)
# Requirement already satisfied: decorator in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (5.1.1)
# Requirement already satisfied: stack-data in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.2.0)
# Requirement already satisfied: colorama in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.4.6)
# Requirement already satisfied: backcall in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\manas\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (3.0.36)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\manas\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.0->jupyter_tensorboard) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\manas\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->notebook>=5.0->jupyter_tensorboard) (22.1.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\manas\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\manas\anaconda3\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (0.58.0)
# Requirement already satisfied: six>=1.5 in c:\users\manas\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=5.3.4->notebook>=5.0->jupyter_tensorboard) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\manas\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=5.0->jupyter_tensorboard) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\manas\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\manas\anaconda3\lib\site-packages (from bleach->nbconvert>=5->notebook>=5.0->jupyter_tensorboard) (0.5.1)
# Requirement already satisfied: idna>=2.8 in c:\users\manas\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\manas\anaconda3\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=5.0->jupyter_tensorboard) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\manas\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=5.0->jupyter_tensorboard) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\manas\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\manas\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\manas\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\manas\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (2.0.5)
# Requirement already satisfied: executing in c:\users\manas\anaconda3\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->notebook>=5.0->jupyter_tensorboard) (0.8.3)

# %%
# %tensorboard --logdir logs/ --port=6066
# Out:
#       <iframe id="tensorboard-frame-2b09f3e0ead49478" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2b09f3e0ead49478");
#           const url = new URL("/", window.location);
#           const port = 6066;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from pstats import Stats
from io import StringIO

# %%
# Printing stats to a string
result=StringIO()
stats = Stats("./logs/cifar10.prof",stream=result)
stats.strip_dirs()
stats.sort_stats('cumulative')
stats.print_stats()

result=result.getvalue()

# Chopping the string into a csv-like buffer
result='ncalls'+result.split('ncalls')[-1]
result='\n'.join([', '.join(line.rstrip().split(None,6)) for line in result.split('\n')])
print(result)

# Saving it to the local disk
f=open('./logs/cifar10.csv','w')
f.write(result)
f.close()
# Out:
# ncalls, tottime, percall, cumtime, percall, filename:lineno(function)
# 4/1, 0.000, 0.000, 7819.840, 7819.840, {built-in, method builtins.exec}
# 1, 0.000, 0.000, 7819.840, 7819.840, <string>:1(<module>)
# 1, 0.000, 0.000, 7819.840, 7819.840, memory_profiler.py:1140(wrapper)
# 1, 0.005, 0.005, 7819.840, 7819.840, memory_profiler.py:715(f)
# 1, 7.831, 7.831, 7819.833, 7819.833, 1201675695.py:3(fit)
# 2220178, 6829.180, 0.003, 6829.432, 0.003, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_FastPathExecute}
# 4689, 1.344, 0.000, 5043.665, 1.076, backprop.py:1007(gradient)
# 4689, 0.093, 0.000, 5027.877, 1.072, imperative_grad.py:29(imperative_grad)
# 4689, 102.390, 0.022, 5027.669, 1.072, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeGradient}
# 281340, 7.376, 0.000, 4898.969, 0.017, backprop.py:127(_gradient_function)
# 37512, 2.383, 0.000, 4276.038, 0.114, nn_grad.py:563(_Conv2DGrad)
# 37512, 1.919, 0.000, 2277.090, 0.061, gen_nn_ops.py:1483(conv2d_backprop_input)
# 2586979/1826140, 21.868, 0.000, 1978.766, 0.001, traceback_utils.py:138(error_handler)
# 37512, 2.519, 0.000, 1966.119, 0.052, gen_nn_ops.py:1307(conv2d_backprop_filter)
# 1533634/1507260, 15.457, 0.000, 1879.065, 0.001, dispatch.py:1162(op_dispatch_handler)
# 258888/5628, 3.016, 0.000, 1832.626, 0.326, traceback_utils.py:59(error_handler)
# 67536/5628, 0.624, 0.000, 1832.526, 0.326, training.py:525(__call__)
# 191352/5628, 26.968, 0.000, 1832.373, 0.326, base_layer.py:987(__call__)
# 191352/5628, 4.165, 0.000, 1824.143, 0.324, traceback_utils.py:92(error_handler)
# 5628, 1.596, 0.000, 1824.044, 0.324, 3051841859.py:25(call)
# 16884, 3.738, 0.000, 1708.974, 0.101, 4239356372.py:21(call)
# 45024, 23.807, 0.001, 1699.628, 0.038, 1206929776.py:15(call)
# 45024, 1.270, 0.000, 1191.551, 0.026, base_conv.py:272(call)
# 45024, 0.792, 0.000, 1187.808, 0.026, base_conv.py:247(convolution_op)
# 45024, 0.608, 0.000, 1185.763, 0.026, nn_ops.py:1171(convolution_v2)
# 45024, 3.309, 0.000, 1185.155, 0.026, nn_ops.py:1197(convolution_internal)
# 45024, 0.906, 0.000, 1179.584, 0.026, nn_ops.py:2773(_conv2d_expanded_batch)
# 45024, 2.073, 0.000, 1178.534, 0.026, gen_nn_ops.py:1098(conv2d)
# 4689, 0.087, 0.000, 795.625, 0.170, optimizer.py:1107(apply_gradients)
# 4689, 0.507, 0.000, 773.091, 0.165, optimizer.py:595(apply_gradients)
# 4689, 0.038, 0.000, 770.875, 0.164, optimizer.py:1165(_internal_apply_gradients)
# 4689, 0.054, 0.000, 770.837, 0.164, merge_call_interim.py:29(maybe_merge_call)
# 4689, 1.039, 0.000, 770.688, 0.164, optimizer.py:1204(_distributed_apply_gradients_fn)
# 117225, 2.329, 0.000, 767.713, 0.007, distribute_lib.py:2564(update)
# 117225, 0.414, 0.000, 745.013, 0.006, distribute_lib.py:3707(_update)
# 117225, 1.383, 0.000, 744.599, 0.006, distribute_lib.py:3712(_update_non_slot)
# 121914, 0.944, 0.000, 740.103, 0.006, api.py:593(wrapper)
# 117225, 0.445, 0.000, 734.360, 0.006, optimizer.py:1209(apply_grad_to_update_var)
# 117225, 0.872, 0.000, 733.915, 0.006, optimizer.py:210(_update_step)
# 117225, 79.486, 0.001, 730.292, 0.006, sgd.py:153(update_step)
# 37512, 0.436, 0.000, 371.936, 0.010, nn_grad.py:923(_FusedBatchNormV3Grad)
# 37512, 2.581, 0.000, 371.500, 0.010, nn_grad.py:831(_BaseFusedBatchNormGrad)
# 734322, 9.105, 0.000, 361.839, 0.000, math_ops.py:1399(binary_op_wrapper)
# 37512, 1.982, 0.000, 360.383, 0.010, gen_nn_ops.py:4598(fused_batch_norm_grad_v3)
# 45024, 3.171, 0.000, 329.944, 0.007, batch_normalization.py:821(call)
# 45024, 4.545, 0.000, 323.527, 0.007, batch_normalization.py:574(_fused_batch_norm)
# 45024, 0.402, 0.000, 270.389, 0.006, control_flow_util.py:87(smart_cond)
# 45042, 0.455, 0.000, 269.829, 0.006, smart_cond.py:23(smart_cond)
# 45024, 2.022, 0.000, 266.911, 0.006, nn_impl.py:1597(fused_batch_norm)
# 37512, 0.626, 0.000, 247.982, 0.007, batch_normalization.py:632(_fused_batch_norm_training)
# 45024, 2.007, 0.000, 241.142, 0.005, gen_nn_ops.py:4873(fused_batch_norm_v3)
# 483915, 1.835, 0.000, 200.176, 0.000, math_ops.py:1760(_mul_dispatch)
# 483916, 1.685, 0.000, 187.638, 0.000, math_ops.py:480(multiply)
# 488605, 7.174, 0.000, 186.134, 0.000, gen_math_ops.py:7305(mul)
# 234450, 1.379, 0.000, 143.150, 0.001, variables.py:1088(_run_op)
# 245707, 1.894, 0.000, 131.220, 0.001, math_ops.py:1729(_add_dispatch)
# 245716, 3.749, 0.000, 127.710, 0.001, gen_math_ops.py:471(add_v2)
# 37512, 0.326, 0.000, 110.634, 0.003, nn_grad.py:411(_ReluGrad)
# 37512, 1.053, 0.000, 110.307, 0.003, gen_nn_ops.py:11521(relu_grad)
# 192249, 7.183, 0.000, 105.957, 0.001, resource_variable_ops.py:908(assign)
# 18756, 0.454, 0.000, 103.059, 0.005, nn_grad.py:676(_MaxPoolGrad)
# 234450, 3.549, 0.000, 102.168, 0.000, gen_math_ops.py:7479(neg)
# 6, 0.010, 0.002, 97.690, 16.282, summary_ops_v2.py:1337(trace_export)
# 31/25, 0.001, 0.000, 97.660, 3.906, deprecation.py:344(new_func)
# 12, 97.315, 8.110, 97.316, 8.110, profiler.py:88(stop)
# 18756, 0.729, 0.000, 91.708, 0.005, gen_nn_ops.py:6494(max_pool_grad)
# 45024, 1.009, 0.000, 81.468, 0.002, gen_nn_ops.py:11317(relu)
# 126603, 2.764, 0.000, 78.398, 0.001, resource_variable_ops.py:873(assign_add)
# 916611, 8.190, 0.000, 68.981, 0.000, trace.py:178(wrapped)
# 758837/758836, 15.242, 0.000, 64.344, 0.000, nest.py:809(map_structure)
# 318852, 3.133, 0.000, 59.987, 0.000, resource_variable_ops.py:898(_lazy_read)
# 916611, 16.500, 0.000, 51.294, 0.000, ops.py:1568(convert_to_tensor)
# 75024, 1.058, 0.000, 45.766, 0.001, base_layer.py:1698(add_update)
# 318984/318918, 2.143, 0.000, 45.699, 0.000, variables.py:266(__call__)
# 445455, 4.156, 0.000, 44.177, 0.000, backprop.py:111(get_attr)
# 318852, 5.260, 0.000, 43.400, 0.000, resource_variable_ops.py:2242(__init__)
# 324498, 2.680, 0.000, 43.318, 0.000, resource_variable_ops.py:579(value)
# 75024, 1.082, 0.000, 42.084, 0.001, batch_normalization.py:566(_assign_new_value)
# 445455, 5.797, 0.000, 38.836, 0.000, backprop.py:81(make_attr)
# 318918, 11.998, 0.000, 36.148, 0.000, resource_variable_ops.py:335(__init__)
# 126603, 1.713, 0.000, 35.734, 0.000, gen_resource_variable_ops.py:23(assign_add_variable_op)
# 324498, 3.258, 0.000, 35.195, 0.000, resource_variable_ops.py:679(_read_variable_op)
# 22512, 0.421, 0.000, 34.311, 0.002, base_pooling2d.py:77(call)
# 22512, 1.199, 0.000, 33.238, 0.001, nn_ops.py:4846(max_pool)
# 782313, 2.500, 0.000, 30.966, 0.000, nest.py:692(pack_sequence_as)
# 22512, 0.592, 0.000, 30.727, 0.001, gen_nn_ops.py:6021(max_pool)
# 782313, 8.539, 0.000, 28.466, 0.000, nest.py:652(_pack_sequence_as)
# 4039604, 12.625, 0.000, 25.664, 0.000, context.py:2149(executing_eagerly)
# 2847566/1875248, 3.550, 0.000, 25.614, 0.000, {built-in, method builtins.next}
# 37512, 0.259, 0.000, 25.098, 0.001, batch_normalization.py:676(mean_update)
# 192315, 2.874, 0.000, 23.984, 0.000, gen_resource_variable_ops.py:123(assign_variable_op)
# 289803, 4.206, 0.000, 23.962, 0.000, math_ops.py:937(cast)
# 324498, 3.261, 0.000, 23.922, 0.000, resource_variable_ops.py:693(read_and_set_handle)
# 4689, 0.039, 0.000, 22.446, 0.005, optimizer.py:1093(aggregate_gradients)
# 4689, 0.534, 0.000, 22.408, 0.005, utils.py:23(all_reduce_sum_gradients)
# 4689, 0.467, 0.000, 21.245, 0.005, distribute_lib.py:3178(all_reduce)
# 7512, 0.087, 0.000, 21.181, 0.003, batch_normalization.py:647(_fused_batch_norm_inference)
# 1423772/937622, 2.990, 0.000, 20.404, 0.000, contextlib.py:114(__enter__)
# 4692, 0.031, 0.000, 19.703, 0.004, notebook.py:256(__iter__)
# 4692, 0.095, 0.000, 19.672, 0.004, std.py:1174(__iter__)
# 159426/4689, 0.296, 0.000, 19.276, 0.004, base_layer.py:2255(trainable_variables)
# 56268/4689, 0.651, 0.000, 19.259, 0.004, training.py:2694(trainable_weights)
# 4689, 0.012, 0.000, 18.909, 0.004, custom_gradient.py:341(__call__)
# 4689, 0.062, 0.000, 18.897, 0.004, custom_gradient.py:292(decorated)
# 4689, 0.419, 0.000, 18.800, 0.004, custom_gradient.py:539(_eager_mode_decorator)
# 758837/758836, 2.546, 0.000, 18.771, 0.000, nest.py:917(<listcomp>)
# 90048, 0.281, 0.000, 18.043, 0.000, resource_variable_ops.py:2226(_dense_var_to_tensor)
# 324498, 4.468, 0.000, 17.849, 0.000, gen_resource_variable_ops.py:552(read_variable_op)
# 90048, 0.422, 0.000, 17.762, 0.000, resource_variable_ops.py:1460(_dense_var_to_tensor)
# 37512, 0.269, 0.000, 17.514, 0.000, batch_normalization.py:693(variance_update)
# 191383, 8.667, 0.000, 17.384, 0.000, input_spec.py:169(assert_input_compatibility)
# 698047/698032, 1.315, 0.000, 16.430, 0.000, {built-in, method builtins.any}
# 203554, 2.904, 0.000, 15.750, 0.000, tensor_shape.py:1243(is_compatible_with)
# 9378, 0.145, 0.000, 15.386, 0.002, backprop.py:632(_aggregate_grads)
# 9378, 0.232, 0.000, 15.153, 0.002, gen_math_ops.py:395(add_n)
# 737664, 4.021, 0.000, 14.626, 0.000, ops.py:5925(init_scope)
# 1237306, 6.083, 0.000, 14.559, 0.000, ops.py:6721(name_scope)
# 620862, 2.006, 0.000, 14.467, 0.000, base_layer.py:3227(_flatten_layers)
# 724020, 10.640, 0.000, 14.300, 0.000, base_layer.py:3234(_flatten_modules)
# 191352, 0.695, 0.000, 14.287, 0.000, base_layer.py:3649(_convert_numpy_or_python_types)
# 197015/197003, 5.942, 0.000, 13.637, 0.000, nest.py:612(_packed_nest_with_indices)
# 643350, 2.750, 0.000, 13.034, 0.000, resource_variable_ops.py:323(variable_accessed)
# 699031, 3.003, 0.000, 12.832, 0.000, ops.py:1252(shape)
# 4689, 0.034, 0.000, 12.701, 0.003, notebook.py:269(update)
# 4689, 0.142, 0.000, 12.667, 0.003, std.py:1212(update)
# 5345622, 12.573, 0.000, 12.573, 0.000, context.py:950(executing_eagerly)
# 4689, 0.074, 0.000, 12.450, 0.003, std.py:1339(refresh)
# 4695, 0.266, 0.000, 12.304, 0.003, notebook.py:149(display)
# 4689, 0.208, 0.000, 11.926, 0.003, math_grad.py:234(_MaxGrad)
# 1423772/937622, 7.319, 0.000, 11.924, 0.000, contextlib.py:123(__exit__)
# 4689, 0.402, 0.000, 11.718, 0.002, math_grad.py:213(_MinOrMaxGrad)
# 21612094, 5.500, 0.000, 11.286, 0.000, {built-in, method builtins.isinstance}
# 56268, 0.139, 0.000, 11.184, 0.000, training.py:3518(_assert_weights_created)
# 56268, 0.097, 0.000, 11.045, 0.000, base_layer.py:1192(dynamic)
# 2187595, 8.887, 0.000, 11.004, 0.000, dtypes.py:215(__eq__)
# 440766, 0.780, 0.000, 10.691, 0.000, base_layer.py:1195(<genexpr>)
# 14496, 0.052, 0.000, 10.584, 0.001, traitlets.py:720(__set__)
# 473994, 3.191, 0.000, 10.577, 0.000, tensor_shape.py:764(__init__)
# 14538, 0.142, 0.000, 10.533, 0.001, traitlets.py:702(set)
# 187560, 3.376, 0.000, 10.510, 0.000, backprop.py:674(_zeros)
# 1423772, 3.284, 0.000, 10.282, 0.000, contextlib.py:261(helper)
# 9958, 0.080, 0.000, 9.998, 0.001, traitlets.py:1500(_notify_trait)
# 2533064, 5.132, 0.000, 9.954, 0.000, tensor_shape.py:722(as_dimension)
# 9730, 0.165, 0.000, 9.914, 0.001, widget.py:596(notify_change)
# 191352, 2.168, 0.000, 9.810, 0.000, base_layer.py:2557(_set_training_mode)
# 191352, 0.629, 0.000, 9.717, 0.000, ops.py:1426(convert_to_tensor_v2_with_dispatch)
# 819889, 1.882, 0.000, 9.627, 0.000, tensor_shape.py:843(dims)
# 191352, 1.070, 0.000, 9.089, 0.000, ops.py:1494(convert_to_tensor_v2)
# 9688, 0.146, 0.000, 8.996, 0.001, widget.py:473(send_state)
# 5339869/5339840, 2.276, 0.000, 8.860, 0.000, {built-in, method builtins.hasattr}
# 153154, 0.722, 0.000, 8.672, 0.000, constant_op.py:170(constant)
# 1805987, 4.208, 0.000, 8.538, 0.000, nest.py:356(flatten)
# 9688, 0.070, 0.000, 8.221, 0.001, widget.py:734(_send)
# 153154, 2.309, 0.000, 7.950, 0.000, constant_op.py:271(_constant_impl)
# 9688, 0.071, 0.000, 7.917, 0.001, base_comm.py:111(send)
# 9754, 0.320, 0.000, 7.890, 0.001, comm.py:21(publish_msg)
# 819889, 2.233, 0.000, 7.745, 0.000, tensor_shape.py:855(<listcomp>)
# 191352, 1.146, 0.000, 7.550, 0.000, traceback_utils.py:77(inject_argument_info_in_traceback)
# 121915, 1.996, 0.000, 7.532, 0.000, api.py:492(tf_convert)
# 191352, 1.486, 0.000, 7.525, 0.000, contextlib.py:438(enter_context)
# 5634, 0.026, 0.000, 7.213, 0.001, iterator_ops.py:785(__next__)
# 5634, 0.218, 0.000, 7.187, 0.001, iterator_ops.py:750(_next_internal)
# 1183260, 2.507, 0.000, 7.172, 0.000, tensor_shape.py:774(<genexpr>)
# 627467, 3.044, 0.000, 7.117, 0.000, distribution_strategy_context.py:76(_get_per_thread_mode)
# 1423772, 6.687, 0.000, 6.999, 0.000, contextlib.py:86(__init__)
# 126680, 0.431, 0.000, 6.925, 0.000, tensor_conversion_registry.py:46(_default_conversion_function)
# 9757, 0.592, 0.000, 6.899, 0.001, session.py:751(send)
# 1350543, 3.428, 0.000, 6.851, 0.000, nest.py:256(_yield_value)
# 2845867, 4.664, 0.000, 6.804, 0.000, traceback_utils.py:32(is_traceback_filtering_enabled)
# 1759584, 5.261, 0.000, 6.803, 0.000, dtypes.py:719(as_dtype)
# 1806784, 3.236, 0.000, 6.766, 0.000, ops.py:6314(get_default_graph)
# 207273, 2.494, 0.000, 6.713, 0.000, tape.py:104(variable_accessed)
# 271151, 4.756, 0.000, 6.677, 0.000, ops.py:6974(__enter__)
# 196067, 3.955, 0.000, 6.595, 0.000, tf_decorator.py:61(make_decorator)
# 1069650, 6.483, 0.000, 6.483, 0.000, trace.py:50(__init__)
# 191352, 3.964, 0.000, 6.363, 0.000, contextlib.py:489(__exit__)
# 121914, 1.880, 0.000, 6.272, 0.000, backprop_util.py:49(IsTrainable)
# 117225, 0.555, 0.000, 6.163, 0.000, distribute_lib.py:3617(__enter__)
# 103158, 0.899, 0.000, 6.101, 0.000, base_layer.py:1284(trainable_weights)
# 3649358, 3.972, 0.000, 5.787, 0.000, abc.py:117(__instancecheck__)
# 1517676, 2.466, 0.000, 5.569, 0.000, nest.py:913(<genexpr>)
# 191352, 2.480, 0.000, 5.520, 0.000, base_layer.py:2688(_maybe_cast_inputs)
# 45024, 1.041, 0.000, 5.370, 0.000, backend.py:322(learning_phase)
# 37512, 0.255, 0.000, 5.303, 0.000, array_ops.py:700(shape_n)
# 9378, 0.068, 0.000, 5.263, 0.001, composite_tensor_gradient.py:173(replace_flat_tensors_for_gradients)
# 5628, 0.562, 0.000, 5.121, 0.001, base_layer.py:2355(_clear_losses)
# 37512, 0.633, 0.000, 5.049, 0.000, gen_array_ops.py:11712(shape_n)
# 202650, 3.424, 0.000, 4.899, 0.000, nest.py:185(_sequence_like)
# 401407, 1.378, 0.000, 4.887, 0.000, ops.py:6030(executing_eagerly_outside_functions)
# 324538, 0.844, 0.000, 4.852, 0.000, ops.py:5601(colocate_with)
# 234475, 1.823, 0.000, 4.726, 0.000, optimizer.py:1076(_var_key)
# 234450, 0.678, 0.000, 4.634, 0.000, variable_scope.py:2865(variable_creator_scope)
# 2195354, 4.400, 0.000, 4.545, 0.000, tensor_shape.py:198(__init__)
# 7570758/7569422, 3.845, 0.000, 4.455, 0.000, {built-in, method builtins.getattr}
# 1688744, 3.958, 0.000, 4.330, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.Flatten}
# 121914, 0.913, 0.000, 4.134, 0.000, api.py:590(call_with_unspecified_conversion_status)
# 734323, 4.113, 0.000, 4.113, 0.000, math_ops.py:1344(maybe_promote_tensors)
# 5365694, 4.110, 0.000, 4.110, 0.000, context.py:2119(context_safe)
# 4689, 0.024, 0.000, 4.088, 0.001, distribute_lib.py:3268(grad_wrapper)
# 4689, 0.079, 0.000, 4.064, 0.001, distribute_lib.py:3077(merge_call)
# 153140, 0.740, 0.000, 4.042, 0.000, constant_op.py:302(_constant_eager_impl)
# 324538, 1.611, 0.000, 4.008, 0.000, ops.py:5578(_colocate_with_for_gradient)
# 319081, 1.990, 0.000, 3.954, 0.000, dtypes.py:172(is_compatible_with)
# 4689, 0.282, 0.000, 3.896, 0.001, custom_gradient.py:565(<listcomp>)
# 5634, 0.114, 0.000, 3.673, 0.001, gen_dataset_ops.py:3022(iterator_get_next)
# 117250, 1.472, 0.000, 3.628, 0.000, gen_array_ops.py:4821(identity)
# 281454, 1.374, 0.000, 3.594, 0.000, registry.py:81(lookup)
# 4689, 0.177, 0.000, 3.572, 0.001, custom_gradient.py:567(<listcomp>)
# 4689, 0.052, 0.000, 3.532, 0.001, distribute_lib.py:3112(_merge_call)
# 1806784, 3.530, 0.000, 3.530, 0.000, ops.py:5843(get_default)
# 5628, 0.033, 0.000, 3.528, 0.001, global_max_pooling2d.py:71(call)
# 1350565, 3.408, 0.000, 3.424, 0.000, nest.py:261(_yield_sorted_items)
# 171627, 0.501, 0.000, 3.402, 0.000, distribution_strategy_context.py:253(has_strategy)
# 5628, 0.021, 0.000, 3.382, 0.001, backend.py:2735(max)
# 153140, 2.294, 0.000, 3.301, 0.000, constant_op.py:74(convert_to_eager_tensor)
# 1069650, 3.285, 0.000, 3.285, 0.000, trace.py:121(__exit__)
# 878439, 1.790, 0.000, 3.278, 0.000, dtypes.py:76(base_dtype)
# 9757, 0.272, 0.000, 3.268, 0.000, session.py:687(serialize)
# 4689, 0.038, 0.000, 3.261, 0.001, distribute_lib.py:3253(batch_all_reduce)
# 5628, 0.038, 0.000, 3.248, 0.001, math_ops.py:3059(reduce_max)
# 5628, 0.063, 0.000, 3.199, 0.001, math_ops.py:3109(reduce_max_with_dims)
# 103158, 0.916, 0.000, 3.192, 0.000, base_layer.py:3210(_gather_children_attribute)
# 5628, 0.183, 0.000, 3.107, 0.001, gen_math_ops.py:6771(_max)
# 5628, 0.022, 0.000, 3.087, 0.001, nn_ops.py:4404(sparse_softmax_cross_entropy_with_logits_v2)
# 207273, 0.513, 0.000, 3.038, 0.000, distribution_strategy_context.py:269(get_strategy_and_replica_context)
# 191352, 0.859, 0.000, 3.010, 0.000, base_layer.py:3639(_in_functional_construction_mode)
# 637704, 0.958, 0.000, 2.987, 0.000, resource_variable_ops.py:240(_handle_graph)
# 4689, 0.029, 0.000, 2.962, 0.001, math_ops.py:445(divide)
# 5628, 0.465, 0.000, 2.938, 0.001, nn_ops.py:4278(sparse_softmax_cross_entropy_with_logits)
# 4689, 0.046, 0.000, 2.883, 0.001, distribute_lib.py:2393(batch_reduce_to)
# 737664, 2.115, 0.000, 2.863, 0.000, tape.py:150(stop_recording)
# 10317, 0.047, 0.000, 2.862, 0.000, math_ops.py:1889(equal)
# 10317, 0.166, 0.000, 2.815, 0.000, gen_math_ops.py:3636(equal)
# 15945, 0.085, 0.000, 2.799, 0.000, math_ops.py:2249(reduce_sum)
# 271151, 1.059, 0.000, 2.790, 0.000, ops.py:7008(__exit__)
# 117225, 0.743, 0.000, 2.771, 0.000, distribute_lib.py:3626(__exit__)
# 4689, 0.020, 0.000, 2.768, 0.001, distribute_lib.py:2465(_batch_reduce_to)
# 191352, 1.081, 0.000, 2.748, 0.000, base_layer.py:2719(_should_cast_single_input)
# 4689, 0.244, 0.000, 2.747, 0.001, distribute_lib.py:2466(<listcomp>)
# 5628, 0.215, 0.000, 2.697, 0.000, gen_math_ops.py:6832(_max_eager_fallback)
# 191352, 1.465, 0.000, 2.673, 0.000, base_layer.py:2868(_get_input_masks)
# 4689, 0.019, 0.000, 2.639, 0.001, math_ops.py:1559(truediv)
# 4689, 0.127, 0.000, 2.620, 0.001, math_ops.py:1510(_truediv_python3)
# 400692/397887, 1.063, 0.000, 2.595, 0.000, traitlets.py:689(__get__)
# 171652, 0.324, 0.000, 2.590, 0.000, distribution_strategy_context.py:233(get_strategy)
# 5629, 0.049, 0.000, 2.523, 0.000, structure.py:228(from_compatible_tensor_list)
# 117225, 0.783, 0.000, 2.503, 0.000, distribute_lib.py:2305(reduce_to)
# 121940, 2.176, 0.000, 2.493, 0.000, functools.py:35(update_wrapper)
# 5629, 0.176, 0.000, 2.474, 0.000, structure.py:193(_from_tensor_list_helper)
# 5628, 0.181, 0.000, 2.467, 0.000, dense.py:179(call)
# 337698, 1.366, 0.000, 2.343, 0.000, tensor_shape.py:270(is_compatible_with)
# 2426227, 2.330, 0.000, 2.330, 0.000, resource_variable_ops.py:574(handle)
# 15006, 0.262, 0.000, 2.291, 0.000, gen_math_ops.py:6680(mat_mul)
# 286341, 0.667, 0.000, 2.270, 0.000, compat.py:115(as_str)
# 2718130, 2.269, 0.000, 2.269, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsNested}
# 590814, 1.159, 0.000, 2.263, 0.000, composite_tensor_gradient.py:105(_get_tensors_for_gradient)
# 103158, 0.363, 0.000, 2.245, 0.000, base_layer.py:3221(<genexpr>)
# 1255378, 1.966, 0.000, 2.233, 0.000, ops.py:1125(dtype)
# 324498, 0.882, 0.000, 2.192, 0.000, resource_variable_ops.py:312(_maybe_set_handle_data)
# 39028, 0.343, 0.000, 2.190, 0.000, session.py:97(json_packer)
# 4689, 0.118, 0.000, 2.062, 0.000, math_grad.py:1717(_MatMulGrad)
# 4689, 0.078, 0.000, 2.034, 0.000, gen_math_ops.py:8674(real_div)
# 50652, 1.159, 0.000, 2.029, 0.000, base_layer.py:2828(_set_mask_metadata)
# 9757, 0.049, 0.000, 2.019, 0.000, iostream.py:283(send_multipart)
# 23445, 0.072, 0.000, 2.005, 0.000, composite_tensor_gradient.py:159(get_flat_tensors_for_gradients)
# 329248, 0.664, 0.000, 1.975, 0.000, dtypes.py:228(__ne__)
# 9757, 0.032, 0.000, 1.970, 0.000, iostream.py:214(send_multipart)
# 9787, 0.097, 0.000, 1.939, 0.000, iostream.py:202(schedule)
# 318984, 1.926, 0.000, 1.927, 0.000, variables.py:155(validate_synchronization_aggregation_trainable)
# 117225, 0.221, 0.000, 1.899, 0.000, distribute_lib.py:866(scope)
# 5628, 0.327, 0.000, 1.890, 0.000, math_ops.py:3489(matmul)
# 196067, 1.613, 0.000, 1.862, 0.000, tf_decorator.py:229(__init__)
# 39028, 0.451, 0.000, 1.832, 0.000, __init__.py:183(dumps)
# 23445, 0.472, 0.000, 1.831, 0.000, composite_tensor_gradient.py:170(<listcomp>)
# 3649358, 1.812, 0.000, 1.815, 0.000, {built-in, method _abc._abc_instancecheck}
# 9787, 1.696, 0.000, 1.696, 0.000, socket.py:543(send)
# 4689, 0.211, 0.000, 1.691, 0.000, math_grad.py:141(_SumGrad)
# 191352, 1.244, 0.000, 1.679, 0.000, base_layer_utils.py:501(enter)
# 117225, 0.321, 0.000, 1.678, 0.000, distribute_lib.py:3646(_scope)
# 319981, 0.593, 0.000, 1.667, 0.000, {built-in, method builtins.all}
# 159426, 1.512, 0.000, 1.666, 0.000, base_layer.py:3319(_dedup_weights)
# 234450, 1.160, 0.000, 1.647, 0.000, ops.py:3223(_variable_creator_scope)
# 489548, 0.377, 0.000, 1.623, 0.000, {method, 'extendleft' of 'collections.deque' objects}
# 239139, 0.586, 0.000, 1.608, 0.000, backprop.py:731(_handle_or_self)
# 286341, 1.054, 0.000, 1.603, 0.000, compat.py:89(as_text)
# 1561772, 1.601, 0.000, 1.601, 0.000, ops.py:176(__exit__)
# 11258, 0.027, 0.000, 1.597, 0.000, structure.py:247(<lambda>)
# 121914, 0.607, 0.000, 1.592, 0.000, backprop_util.py:25(_DTypeFromTensor)
# 271151, 0.672, 0.000, 1.589, 0.000, ops.py:6998(_restore_name_scope)
# 121914, 0.198, 0.000, 1.585, 0.000, distribution_strategy_context.py:144(get_replica_context)
# 1561772, 1.575, 0.000, 1.575, 0.000, ops.py:170(__init__)
# 11258, 0.053, 0.000, 1.571, 0.000, tensor_spec.py:233(_from_compatible_tensor_list)
# 380455/378286, 1.448, 0.000, 1.539, 0.000, traitlets.py:651(get)
# 121914, 0.539, 0.000, 1.519, 0.000, distribute_lib.py:298(_require_cross_replica_or_default_context_extended)
# 11256, 0.043, 0.000, 1.517, 0.000, ops.py:1297(set_shape)
# 542302, 1.508, 0.000, 1.508, 0.000, context.py:967(scope_name)
# 878441, 1.488, 0.000, 1.488, 0.000, dtypes.py:63(_is_ref_dtype)
# 203568, 0.557, 0.000, 1.455, 0.000, tensor_shape.py:1335(is_fully_defined)
# 11274, 0.257, 0.000, 1.440, 0.000, execute.py:225(args_to_matching_eager)
# 18756, 0.125, 0.000, 1.432, 0.000, array_ops.py:63(reshape)
# 45024, 0.212, 0.000, 1.413, 0.000, batch_normalization.py:306(_support_zero_size_input)
# 191352, 0.818, 0.000, 1.399, 0.000, contextlib.py:465(_push_cm_exit)
# 15945, 0.127, 0.000, 1.399, 0.000, math_ops.py:2316(reduce_sum_with_dims)
# 4692, 0.048, 0.000, 1.377, 0.000, tf_inspect.py:247(getfullargspec)
# 117225, 0.573, 0.000, 1.358, 0.000, distribute_lib.py:3607(__init__)
# 851812, 1.264, 0.000, 1.350, 0.000, tensor_shape.py:836(rank)
# 9378, 0.357, 0.000, 1.331, 0.000, composite_tensor_gradient.py:185(<listcomp>)
# 21574, 0.111, 0.000, 1.326, 0.000, math_ops.py:2138(_ReductionDims)
# 4692, 0.285, 0.000, 1.301, 0.000, inspect.py:1129(getfullargspec)
# 103158, 0.258, 0.000, 1.289, 0.000, base_layer.py:3174(_update_trackables)
# 1561772, 1.259, 0.000, 1.259, 0.000, ops.py:173(__enter__)
# 380750, 0.730, 0.000, 1.246, 0.000, _collections_abc.py:996(__reversed__)
# 15945, 0.255, 0.000, 1.215, 0.000, gen_math_ops.py:12432(_sum)
# 636918, 1.044, 0.000, 1.214, 0.000, ops.py:5447(_distribution_strategy_stack)
# 9378, 0.307, 0.000, 1.211, 0.000, composite_tensor_gradient.py:183(<listcomp>)
# 1508642, 1.209, 0.000, 1.209, 0.000, tensor_shape.py:264(value)
# 359214, 1.076, 0.000, 1.178, 0.000, tensor_util.py:1030(is_tf_type)
# 4689, 0.043, 0.000, 1.171, 0.000, nn_grad.py:537(_SparseSoftmaxCrossEntropyWithLogitsGrad)
# 18756, 0.300, 0.000, 1.147, 0.000, gen_array_ops.py:10442(reshape)
# 4689, 0.027, 0.000, 1.128, 0.000, nn_grad.py:497(_BroadcastMul)
# 272085, 0.382, 0.000, 1.123, 0.000, tf_utils.py:370(is_extension_type)
# 445455, 1.122, 0.000, 1.122, 0.000, backprop.py:70(op_attr_type)
# 39028, 0.208, 0.000, 1.115, 0.000, encoder.py:182(encode)
# 281340, 1.086, 0.000, 1.086, 0.000, backprop.py:104(__init__)
# 45024, 0.607, 0.000, 1.034, 0.000, layer_utils.py:749(set_arg_value)
# 37611, 0.218, 0.000, 1.031, 0.000, base_layer.py:3182(_track_variables)
# 346182, 1.012, 0.000, 1.023, 0.000, ops.py:434(__getattr__)
# 726795, 0.846, 0.000, 1.022, 0.000, backprop.py:97(<lambda>)
# 4698, 0.866, 0.000, 1.015, 0.000, std.py:355(format_meter)
# 192249, 0.628, 0.000, 0.992, 0.000, compat.py:65(forward_compatible)
# 243830, 0.667, 0.000, 0.984, 0.000, api.py:283(autograph_artifact)
# 234450, 0.545, 0.000, 0.973, 0.000, composite_tensor_gradient.py:128(_replace_tensors_for_gradient)
# 4692, 0.326, 0.000, 0.973, 0.000, inspect.py:2246(_signature_from_callable)
# 135072, 0.918, 0.000, 0.948, 0.000, nn_ops.py:216(_get_sequence)
# 222408, 0.857, 0.000, 0.942, 0.000, tensor_conversion_registry.py:112(get)
# 75024, 0.213, 0.000, 0.939, 0.000, base_layer_utils.py:550(in_keras_graph)
# 382704, 0.880, 0.000, 0.912, 0.000, base_layer.py:1053(<genexpr>)
# 10319, 0.035, 0.000, 0.903, 0.000, array_ops.py:632(shape)
# 5646, 0.081, 0.000, 0.901, 0.000, execute.py:27(quick_execute)
# 1069650, 0.896, 0.000, 0.896, 0.000, trace.py:83(__enter__)
# 332052, 0.594, 0.000, 0.896, 0.000, base_layer.py:3299(_expects_mask_arg)
# 39028, 0.670, 0.000, 0.895, 0.000, encoder.py:204(iterencode)
# 995057, 0.886, 0.000, 0.886, 0.000, resource_variable_ops.py:527(dtype)
# 121916, 0.447, 0.000, 0.878, 0.000, ag_ctx.py:76(__exit__)
# 10319, 0.150, 0.000, 0.868, 0.000, array_ops.py:659(shape_internal)
# 10329, 0.154, 0.000, 0.857, 0.000, gen_math_ops.py:2200(cast)
# 126708, 0.581, 0.000, 0.823, 0.000, tf_decorator.py:193(unwrap)
# 528188, 0.766, 0.000, 0.807, 0.000, tensor_shape.py:1439(as_shape)
# 5646, 0.783, 0.000, 0.783, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_Execute}
# 493300, 0.677, 0.000, 0.776, 0.000, ag_ctx.py:28(_control_ctx)
# 266376, 0.604, 0.000, 0.773, 0.000, base_layer_utils.py:457(call_context)
# 388332, 0.665, 0.000, 0.760, 0.000, base_layer.py:3643(<genexpr>)
# 239139, 0.242, 0.000, 0.742, 0.000, resource_variable_ops.py:2447(is_resource_variable)
# 191352, 0.726, 0.000, 0.726, 0.000, layer_utils.py:797(split_out_first_arg)
# 3363534/3173156, 0.514, 0.000, 0.700, 0.000, {built-in, method builtins.len}
# 187565, 0.415, 0.000, 0.698, 0.000, context.py:958(zeros_cache)
# 505553, 0.698, 0.000, 0.698, 0.000, distribution_strategy_context.py:397(_get_default_replica_mode)
# 643391, 0.694, 0.000, 0.694, 0.000, resource_variable_ops.py:618(trainable)
# 191352, 0.689, 0.000, 0.689, 0.000, base_layer_utils.py:570(__enter__)
# 271151, 0.655, 0.000, 0.680, 0.000, ops.py:6956(__init__)
# 191352, 0.677, 0.000, 0.677, 0.000, base_layer_utils.py:587(__exit__)
# 346418, 0.672, 0.000, 0.672, 0.000, context.py:972(device_name)
# 5680, 0.023, 0.000, 0.640, 0.000, constant_op.py:340(_constant_tensor_conversion_function)
# 4692, 0.426, 0.000, 0.640, 0.000, inspect.py:2152(_signature_from_function)
# 88164, 0.455, 0.000, 0.637, 0.000, __init__.py:437(_make)
# 4689, 0.405, 0.000, 0.628, 0.000, optimizer.py:147(_deduplicate_sparse_grad)
# 9378, 0.611, 0.000, 0.627, 0.000, utils.py:60(filter_empty_gradients)
# 9757, 0.119, 0.000, 0.624, 0.000, session.py:646(msg)
# 5628, 0.083, 0.000, 0.623, 0.000, nn_ops.py:4249(_sparse_softmax_cross_entropy_with_rank_2_logits)
# 5635, 0.107, 0.000, 0.605, 0.000, nest.py:135(pack_sequence_as)
# 5628, 0.034, 0.000, 0.579, 0.000, math_ops.py:267(argmax_v2)
# 191352, 0.351, 0.000, 0.568, 0.000, base_layer.py:3294(_expects_training_arg)
# 45024, 0.325, 0.000, 0.557, 0.000, control_flow_ops.py:3719(get_enclosing_xla_context)
# 207273, 0.471, 0.000, 0.552, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeVariableAccessed}
# 9757, 0.153, 0.000, 0.551, 0.000, session.py:672(sign)
# 5628, 0.089, 0.000, 0.545, 0.000, gen_math_ops.py:845(arg_max)
# 275858, 0.538, 0.000, 0.538, 0.000, context.py:962(scope_name)
# 524388, 0.511, 0.000, 0.511, 0.000, tensor_shape.py:1338(<genexpr>)
# 9721/9700, 0.181, 0.000, 0.508, 0.000, widget.py:492(get_state)
# 5628, 0.115, 0.000, 0.499, 0.000, gen_nn_ops.py:12126(sparse_softmax_cross_entropy_with_logits)
# 10317, 0.146, 0.000, 0.498, 0.000, gen_array_ops.py:11634(shape)
# 196051, 0.355, 0.000, 0.498, 0.000, inspect.py:1548(currentframe)
# 286617, 0.498, 0.000, 0.498, 0.000, {built-in, method _codecs.lookup}
# 175802, 0.488, 0.000, 0.488, 0.000, context.py:558(ensure_initialized)
# 191352, 0.485, 0.000, 0.485, 0.000, autocast_variable.py:565(__init__)
# 50652, 0.115, 0.000, 0.479, 0.000, base_layer.py:2878(<listcomp>)
# 4690, 0.039, 0.000, 0.477, 0.000, deprecation.py:527(new_func)
# 202641, 0.280, 0.000, 0.476, 0.000, nest.py:147(is_namedtuple)
# 127552, 0.274, 0.000, 0.468, 0.000, ag_ctx.py:34(control_status_ctx)
# 191352, 0.411, 0.000, 0.464, 0.000, autocast_variable.py:570(__enter__)
# 191352, 0.460, 0.000, 0.460, 0.000, autocast_variable.py:574(__exit__)
# 121916, 0.261, 0.000, 0.458, 0.000, ag_ctx.py:68(__enter__)
# 380750, 0.425, 0.000, 0.457, 0.000, data_structures.py:441(__len__)
# 11268, 0.107, 0.000, 0.453, 0.000, context.py:2439(execution_mode)
# 101304, 0.149, 0.000, 0.443, 0.000, base_layer.py:2839(<genexpr>)
# 6, 0.000, 0.000, 0.443, 0.074, dataset_ops.py:486(__iter__)
# 381856, 0.442, 0.000, 0.442, 0.000, {method, '_shape_tuple' of 'tensorflow.python.framework.ops.EagerTensor' objects}
# 6, 0.000, 0.000, 0.442, 0.074, iterator_ops.py:665(__init__)
# 6, 0.000, 0.000, 0.442, 0.074, iterator_ops.py:707(_create_iterator)
# 6, 0.000, 0.000, 0.437, 0.073, gen_dataset_ops.py:3420(make_iterator)
# 191352, 0.435, 0.000, 0.435, 0.000, base_layer_utils.py:565(__init__)
# 382672, 0.430, 0.000, 0.430, 0.000, data_structures.py:435(__getitem__)
# 75024, 0.223, 0.000, 0.428, 0.000, backend.py:1058(name_scope)
# 455840, 0.426, 0.000, 0.426, 0.000, distribute_lib.py:846(extended)
# 117225, 0.263, 0.000, 0.419, 0.000, distribute_lib.py:259(__enter__)
# 117225, 0.378, 0.000, 0.418, 0.000, optimizer.py:313(learning_rate)
# 4689, 0.052, 0.000, 0.414, 0.000, backprop.py:702(_ones)
# 4689, 0.094, 0.000, 0.411, 0.000, math_grad.py:1348(_MulGrad)
# 9757, 0.061, 0.000, 0.404, 0.000, session.py:643(msg_header)
# 14858/14840, 0.122, 0.000, 0.395, 0.000, traitlets.py:731(_validate)
# 4689, 0.263, 0.000, 0.388, 0.000, math_ops.py:4500(reduced_shape)
# 75072, 0.278, 0.000, 0.371, 0.000, _collections_abc.py:980(__iter__)
# 4689, 0.025, 0.000, 0.371, 0.000, array_ops.py:302(expand_dims)
# 39618, 0.182, 0.000, 0.366, 0.000, tensor_shape.py:885(__getitem__)
# 192249, 0.363, 0.000, 0.363, 0.000, compat.py:37(_date_to_date_number)
# 90048, 0.322, 0.000, 0.359, 0.000, control_flow_util.py:113(constant_value)
# 45024, 0.183, 0.000, 0.359, 0.000, layer_utils.py:581(wrapped)
# 382735, 0.356, 0.000, 0.356, 0.000, base_layer.py:1178(name)
# 192249, 0.273, 0.000, 0.345, 0.000, context.py:137(get)
# 45024, 0.204, 0.000, 0.343, 0.000, backend.py:407(_internal_get_learning_phase)
# 117225, 0.339, 0.000, 0.339, 0.000, distribute_lib.py:263(__exit__)
# 4689, 0.133, 0.000, 0.334, 0.000, distribute_lib.py:3255(<listcomp>)
# 6, 0.000, 0.000, 0.334, 0.056, profiler.py:135(save)
# 191352, 0.305, 0.000, 0.331, 0.000, contextlib.py:470(_push_exit_callback)
# 75024, 0.257, 0.000, 0.329, 0.000, base_layer_utils.py:543(frozen)
# 82536, 0.314, 0.000, 0.314, 0.000, batch_normalization.py:611(_maybe_add_or_remove_bessels_correction)
# 171627, 0.311, 0.000, 0.311, 0.000, distribution_strategy_context.py:366(_get_default_strategy)
# 22512, 0.164, 0.000, 0.310, 0.000, numeric.py:1873(isscalar)
# 45024, 0.254, 0.000, 0.309, 0.000, batch_normalization.py:809(_get_training_value)
# 368832, 0.308, 0.000, 0.308, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetIsStopped}
# 25349, 0.091, 0.000, 0.305, 0.000, ops.py:1131(numpy)
# 4698, 0.076, 0.000, 0.302, 0.000, std.py:1460(format_dict)
# 332052, 0.302, 0.000, 0.302, 0.000, layer_utils.py:684(expects_mask_arg)
# 9378, 0.193, 0.000, 0.300, 0.000, math_grad.py:1279(_AddGrad)
# 45040, 0.071, 0.000, 0.294, 0.000, ops.py:1265(get_shape)
# 243858, 0.260, 0.000, 0.289, 0.000, inspect.py:81(ismethod)
# 90056, 0.254, 0.000, 0.287, 0.000, weakref.py:452(get)
# 187565, 0.283, 0.000, 0.283, 0.000, context.py:218(zeros_cache)
# 4689, 0.060, 0.000, 0.282, 0.000, custom_gradient.py:45(custom_gradient)
# 9378, 0.033, 0.000, 0.280, 0.000, merge_call_interim.py:20(strategy_supports_no_merge_call)
# 6, 0.278, 0.046, 0.280, 0.047, file_io.py:98(write)
# 191352, 0.280, 0.000, 0.280, 0.000, contextlib.py:408(__init__)
# 1261024, 0.268, 0.000, 0.268, 0.000, {method, '_datatype_enum' of 'tensorflow.python.framework.ops.EagerTensor' objects}
# 2768679, 0.268, 0.000, 0.268, 0.000, {method, 'append' of 'list' objects}
# 117225, 0.267, 0.000, 0.267, 0.000, distribute_lib.py:2123(_container_strategy)
# 39028, 0.266, 0.000, 0.266, 0.000, encoder.py:104(__init__)
# 1, 0.000, 0.000, 0.263, 0.263, dataset_ops.py:2137(map)
# 1, 0.000, 0.000, 0.263, 0.263, dataset_ops.py:5528(__init__)
# 117226, 0.150, 0.000, 0.263, 0.000, {method, 'sort' of 'list' objects}
# 1, 0.000, 0.000, 0.260, 0.260, structured_function.py:80(__init__)
# 1, 0.000, 0.000, 0.258, 0.258, tracing_compiler.py:217(get_concrete_function)
# 1, 0.000, 0.000, 0.258, 0.258, tracing_compiler.py:176(_get_concrete_function_garbage_collected)
# 1, 0.000, 0.000, 0.258, 0.258, tracing_compiler.py:151(_maybe_define_concrete_function)
# 1, 0.000, 0.000, 0.258, 0.258, tracing_compiler.py:303(_maybe_define_function)
# 1, 0.000, 0.000, 0.256, 0.256, tracing_compiler.py:269(_create_concrete_function)
# 3/1, 0.001, 0.000, 0.254, 0.254, func_graph.py:1102(func_graph_from_py_func)
# 4689, 0.023, 0.000, 0.254, 0.000, array_ops.py:375(expand_dims_v2)
# 253206, 0.251, 0.000, 0.251, 0.000, resource_variable_ops.py:470(_assign_dependencies)
# 9688, 0.083, 0.000, 0.251, 0.000, widget.py:644(_should_send_property)
# 191352, 0.250, 0.000, 0.250, 0.000, contextlib.py:398(_create_exit_wrapper)
# 5635, 0.112, 0.000, 0.242, 0.000, nest.py:104(_packed_nest_with_indices)
# 1, 0.000, 0.000, 0.232, 0.232, structured_function.py:234(wrapped_fn)
# 1, 0.000, 0.000, 0.232, 0.232, structured_function.py:165(wrapper_helper)
# 1, 0.000, 0.000, 0.231, 0.231, api.py:681(wrapper)
# 3/1, 0.000, 0.000, 0.231, 0.231, api.py:295(converted_call)
# 4689, 0.070, 0.000, 0.231, 0.000, gen_array_ops.py:2735(expand_dims)
# 45024, 0.165, 0.000, 0.230, 0.000, base_layer.py:2197(compute_dtype)
# 158812, 0.229, 0.000, 0.229, 0.000, context.py:908(_handle)
# 4689, 0.027, 0.000, 0.228, 0.000, <__array_function__, internals>:177(array_equal)
# 117225, 0.227, 0.000, 0.227, 0.000, distribute_lib.py:3698(_reduce_to)
# 4689, 0.071, 0.000, 0.227, 0.000, gen_array_ops.py:14666(tile)
# 19514, 0.076, 0.000, 0.225, 0.000, jsonutil.py:108(json_default)
# 368593, 0.225, 0.000, 0.225, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetStopOnThread}
# 207273, 0.225, 0.000, 0.225, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_VariableWatcherVariableAccessed}
# 45024, 0.224, 0.000, 0.224, 0.000, weakref.py:455(__contains__)
# 14105, 0.059, 0.000, 0.223, 0.000, tensor_util.py:808(constant_value)
# 123887, 0.218, 0.000, 0.218, 0.000, tensor_shape.py:1349(as_list)
# 191352, 0.217, 0.000, 0.217, 0.000, layer_utils.py:675(expects_training_arg)
# 234475, 0.216, 0.000, 0.216, 0.000, optimizer.py:140(_var_key)
# 368593, 0.215, 0.000, 0.215, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetRestartOnThread}
# 126708, 0.197, 0.000, 0.212, 0.000, tf_decorator.py:107(_has_tf_decorator_attr)
# 225120, 0.212, 0.000, 0.212, 0.000, nn_ops.py:1286(<genexpr>)
# 191352, 0.210, 0.000, 0.210, 0.000, base_layer_utils.py:535(training)
# 191383, 0.207, 0.000, 0.207, 0.000, base_layer.py:1236(input_spec)
# 117339, 0.188, 0.000, 0.205, 0.000, ops.py:3333(_variable_creator_stack)
# 5628, 0.023, 0.000, 0.204, 0.000, resource_variable_ops.py:560(_shape_tuple)
# 1522928, 0.204, 0.000, 0.204, 0.000, {method, 'pop' of 'dict' objects}
# 131313, 0.193, 0.000, 0.203, 0.000, inspect.py:159(isfunction)
# 202650, 0.203, 0.000, 0.203, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsMutableMapping}
# 121915, 0.203, 0.000, 0.203, 0.000, ag_ctx.py:64(__init__)
# 117225, 0.193, 0.000, 0.202, 0.000, distribute_lib.py:3557(_batch_reduce_destination)
# 95676, 0.202, 0.000, 0.202, 0.000, layer_utils.py:698(arg_was_passed)
# 14427, 0.084, 0.000, 0.201, 0.000, traitlets.py:740(_cross_validate)
# 4704/4701, 0.015, 0.000, 0.197, 0.000, {built-in, method numpy.core._multiarray_umath.implement_array_function}
# 202641, 0.196, 0.000, 0.196, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsNamedtuple}
# 207273, 0.195, 0.000, 0.195, 0.000, distribute_lib.py:3728(value_container)
# 4698, 0.046, 0.000, 0.191, 0.000, notebook.py:201(colour)
# 20159, 0.125, 0.000, 0.190, 0.000, traitlets.py:1913(trait_metadata)
# 930305, 0.189, 0.000, 0.189, 0.000, {built-in, method builtins.callable}
# 31, 0.001, 0.000, 0.188, 0.006, base_layer.py:2953(_maybe_build)
# 117225, 0.184, 0.000, 0.184, 0.000, distribute_lib.py:255(__init__)
# 5628, 0.042, 0.000, 0.182, 0.000, resource_variable_ops.py:555(_shape_as_list)
# 4689, 0.082, 0.000, 0.181, 0.000, numeric.py:2402(array_equal)
# 9961, 0.041, 0.000, 0.179, 0.000, traitlets.py:1511(notify_change)
# 398106, 0.177, 0.000, 0.177, 0.000, {method, 'pop' of 'list' objects}
# 45042, 0.171, 0.000, 0.176, 0.000, smart_cond.py:60(smart_constant_value)
# 191352, 0.176, 0.000, 0.176, 0.000, {built-in, method sys.exc_info}
# 25352, 0.056, 0.000, 0.171, 0.000, ops.py:1119(_numpy)
# 3, 0.000, 0.000, 0.170, 0.057, __init__.py:20(tqdm_notebook)
# 9721, 0.045, 0.000, 0.169, 0.000, widget.py:118(_remove_buffers)
# 202643, 0.169, 0.000, 0.169, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsCompositeTensor}
# 191352, 0.165, 0.000, 0.165, 0.000, contextlib.py:486(__enter__)
# 3, 0.000, 0.000, 0.164, 0.055, notebook.py:211(__init__)
# 190375, 0.162, 0.000, 0.162, 0.000, data_structures.py:391(_values)
# 18829, 0.046, 0.000, 0.161, 0.000, tensor_util.py:1086(maybe_set_static_shape)
# 1052920, 0.160, 0.000, 0.161, 0.000, {built-in, method builtins.setattr}
# 157560, 0.161, 0.000, 0.161, 0.000, batch_normalization.py:290(trainable)
# 1800053, 0.160, 0.000, 0.160, 0.000, {built-in, method builtins.id}
# 1, 0.000, 0.000, 0.160, 0.160, api.py:260(_convert_actual)
# 1, 0.000, 0.000, 0.160, 0.160, transpiler.py:266(transform)
# 1, 0.000, 0.000, 0.159, 0.159, transpiler.py:432(transform_function)
# 121918, 0.138, 0.000, 0.158, 0.000, api.py:291(is_autograph_artifact)
# 202642, 0.158, 0.000, 0.158, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsTypeSpec}
# 117225, 0.156, 0.000, 0.156, 0.000, distribute_lib.py:242(get_update_replica_id)
# 117225, 0.155, 0.000, 0.155, 0.000, distribution_strategy_context.py:385(_get_default_replica_context)
# 1232595, 0.154, 0.000, 0.155, 0.000, {method, 'add' of 'set' objects}
# 476045, 0.151, 0.000, 0.151, 0.000, {method, 'get' of 'dict' objects}
# 66, 0.001, 0.000, 0.150, 0.002, resource_variable_ops.py:1605(__init__)
# 103104, 0.150, 0.000, 0.150, 0.000, {built-in, method __new__ of type object at 0x00007FFFD932DC60}
# 41, 0.004, 0.000, 0.149, 0.004, base_layer.py:551(add_weight)
# 66, 0.016, 0.000, 0.149, 0.002, resource_variable_ops.py:1749(_init_from_args)
# 202641, 0.147, 0.000, 0.147, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsMappingView}
# 41, 0.001, 0.000, 0.144, 0.004, base.py:438(_add_variable_with_custom_getter)
# 3, 0.000, 0.000, 0.143, 0.048, notebook.py:104(status_printer)
# 10263, 0.132, 0.000, 0.143, 0.000, traitlets.py:1515(_notify_observers)
# 208276, 0.141, 0.000, 0.141, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsAttrs}
# 33/12, 0.000, 0.000, 0.141, 0.012, widget.py:409(__init__)
# 202641, 0.141, 0.000, 0.141, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.IsMapping}
# 121931, 0.139, 0.000, 0.139, 0.000, flags.py:25(config)
# 33/12, 0.001, 0.000, 0.139, 0.012, widget.py:425(open)
# 41, 0.001, 0.000, 0.135, 0.003, base_layer_utils.py:44(make_variable)
# 11268, 0.053, 0.000, 0.132, 0.000, context.py:1056(executor)
# 41, 0.001, 0.000, 0.131, 0.003, variables.py:186(_variable_v1_call)
# 41, 0.000, 0.000, 0.130, 0.003, variables.py:203(<lambda>)
# 41, 0.002, 0.000, 0.130, 0.003, variable_scope.py:2680(default_variable_creator)
# 117225, 0.129, 0.000, 0.129, 0.000, resource_variable_ops.py:603(constraint)
# 9757, 0.056, 0.000, 0.126, 0.000, session.py:599(msg_id)
# 45044, 0.061, 0.000, 0.126, 0.000, tensor_shape.py:857(ndims)
# 9736/9721, 0.115, 0.000, 0.124, 0.000, widget.py:73(_separate_buffers)
# 4768, 0.024, 0.000, 0.122, 0.000, traitlets.py:1226(__call__)
# 2183/41, 0.008, 0.000, 0.122, 0.003, ast.py:403(visit)
# 1, 0.000, 0.000, 0.121, 0.121, transpiler.py:324(transform_function)
# 16905, 0.086, 0.000, 0.121, 0.000, nest.py:49(_yield_value)
# 4689, 0.024, 0.000, 0.120, 0.000, backprop.py:169(record_gradient)
# 4705, 0.073, 0.000, 0.119, 0.000, inspect.py:2498(__init__)
# 25352, 0.115, 0.000, 0.115, 0.000, {method, '_numpy_internal' of 'tensorflow.python.framework.ops.EagerTensor' objects}
# 45024, 0.114, 0.000, 0.114, 0.000, backend.py:359(global_learning_phase_is_set)
# 117225, 0.114, 0.000, 0.114, 0.000, distribute_lib.py:3725(_local_results)
# 9798, 0.061, 0.000, 0.113, 0.000, threading.py:1133(is_alive)
# 117225, 0.112, 0.000, 0.112, 0.000, ops.py:3247(<lambda>)
# 5640, 0.026, 0.000, 0.111, 0.000, array_ops.py:1576(_autopacking_conversion_function)
# 112560, 0.108, 0.000, 0.108, 0.000, nn_ops.py:4894(<genexpr>)
# 22512, 0.105, 0.000, 0.108, 0.000, nn_ops.py:1935(convert_padding)
# 28149, 0.108, 0.000, 0.108, 0.000, std.py:233(__call__)
# 9757, 0.060, 0.000, 0.108, 0.000, hmac.py:115(copy)
# 19514, 0.097, 0.000, 0.107, 0.000, {method, 'isoformat' of 'datetime.datetime' objects}
# 117225, 0.106, 0.000, 0.106, 0.000, resource_variable_ops.py:2368(_ReadGrad)
# 4689, 0.016, 0.000, 0.104, 0.000, backprop.py:868(__enter__)
# 9378, 0.073, 0.000, 0.103, 0.000, math_grad.py:1269(_ShapesFullySpecifiedAndEqual)
# 101304, 0.102, 0.000, 0.102, 0.000, base_layer.py:2879(<genexpr>)
# 1, 0.000, 0.000, 0.102, 0.102, api.py:235(transform_ast)
# 302/116, 0.003, 0.000, 0.102, 0.001, traitlets.py:1856(trait_defaults)
# 9757, 0.042, 0.000, 0.099, 0.000, session.py:273(msg_header)
# 235/91, 0.001, 0.000, 0.097, 0.001, traitlets.py:613(default)
# 21, 0.000, 0.000, 0.096, 0.005, trait_types.py:167(make_dynamic_default)
# 14067, 0.073, 0.000, 0.096, 0.000, math_ops.py:4441(conj)
# 4689, 0.017, 0.000, 0.096, 0.000, {method, 'all' of 'numpy.ndarray' objects}
# 4689, 0.028, 0.000, 0.096, 0.000, sgd.py:132(build)
# 5628, 0.020, 0.000, 0.094, 0.000, execute.py:273(<listcomp>)
# 1485/49, 0.024, 0.000, 0.094, 0.002, ast.py:477(generic_visit)
# 9757, 0.030, 0.000, 0.092, 0.000, hmac.py:147(hexdigest)
# 5634, 0.031, 0.000, 0.091, 0.000, executor.py:72(new_executor)
# 199111, 0.091, 0.000, 0.091, 0.000, {method, 'encode' of 'str' objects}
# 8, 0.001, 0.000, 0.090, 0.011, batch_normalization.py:322(build)
# 11274, 0.034, 0.000, 0.089, 0.000, executor.py:44(__del__)
# 4689, 0.035, 0.000, 0.088, 0.000, backprop.py:878(_push_tape)
# 9754, 0.022, 0.000, 0.087, 0.000, kernelbase.py:617(get_parent)
# 4696, 0.065, 0.000, 0.087, 0.000, inspect.py:2781(__init__)
# 21574, 0.055, 0.000, 0.086, 0.000, math_ops.py:2161(_may_reduce_to_scalar)
# 8, 0.000, 0.000, 0.086, 0.011, base_conv.py:200(build)
# 15946, 0.085, 0.000, 0.085, 0.000, {built-in, method numpy.arange}
# 50652, 0.085, 0.000, 0.085, 0.000, base_layer.py:963(compute_mask)
# 4695, 0.023, 0.000, 0.085, 0.000, widget_float.py:33(_validate_value)
# 5640, 0.022, 0.000, 0.085, 0.000, array_ops.py:1566(_should_not_autopack)
# 992/22, 0.020, 0.000, 0.084, 0.004, transformer.py:417(visit)
# 33, 0.000, 0.000, 0.084, 0.003, comm.py:71(__init__)
# 9390, 0.053, 0.000, 0.083, 0.000, std.py:288(format_interval)
# 22548, 0.031, 0.000, 0.082, 0.000, executor.py:63(wait)
# 9528, 0.048, 0.000, 0.081, 0.000, enum.py:358(__call__)
# 4689, 0.013, 0.000, 0.079, 0.000, _methods.py:60(_all)
# 9787, 0.063, 0.000, 0.078, 0.000, traitlets.py:1882(traits)
# 19511, 0.077, 0.000, 0.077, 0.000, jsonutil.py:77(json_clean)
# 196056, 0.076, 0.000, 0.076, 0.000, {built-in, method sys._getframe}
# 909052, 0.076, 0.000, 0.076, 0.000, {method, 'popleft' of 'collections.deque' objects}
# 56330, 0.075, 0.000, 0.075, 0.000, resource_variable_ops.py:547(shape)
# 5628, 0.008, 0.000, 0.074, 0.000, ops.py:7171(_is_keras_symbolic_tensor)
# 6, 0.000, 0.000, 0.074, 0.012, widget_string.py:29(__init__)
# 39028, 0.049, 0.000, 0.072, 0.000, hmac.py:111(update)
# 4695, 0.023, 0.000, 0.071, 0.000, re.py:223(split)
# 4707, 0.024, 0.000, 0.071, 0.000, ops.py:6348(get_name_scope)
# 4689, 0.013, 0.000, 0.071, 0.000, distribute_lib.py:330(require_replica_context)
# 191352, 0.070, 0.000, 0.070, 0.000, {method, 'pop' of 'collections.deque' objects}
# 1, 0.000, 0.000, 0.070, 0.070, __autograph_generated_file6jojo59y.py:5(<lambda>)
# 1, 0.000, 0.000, 0.070, 0.070, function_wrappers.py:110(with_function_scope)
# 45069, 0.069, 0.000, 0.069, 0.000, ops.py:3461(_get_control_flow_context)
# 2, 0.000, 0.000, 0.068, 0.034, api.py:449(_call_unconverted)
# 5640, 0.033, 0.000, 0.068, 0.000, context.py:1050(executor)
# 4698, 0.067, 0.000, 0.067, 0.000, {method, 'reduce' of 'numpy.ufunc' objects}
# 66, 0.002, 0.000, 0.066, 0.001, base_comm.py:24(__init__)
# 11, 0.005, 0.000, 0.065, 0.006, random_ops.py:212(random_uniform)
# 45064, 0.064, 0.000, 0.064, 0.000, policy.py:274(compute_dtype)
# 32889, 0.063, 0.000, 0.063, 0.000, {method, 'format' of 'str' objects}
# 65646, 0.062, 0.000, 0.062, 0.000, base_layer.py:1206(trainable)
# 223276, 0.059, 0.000, 0.060, 0.000, {built-in, method builtins.issubclass}
# 22512, 0.058, 0.000, 0.058, 0.000, conv_utils.py:25(convert_data_format)
# 9757, 0.048, 0.000, 0.058, 0.000, session.py:846(<listcomp>)
# 27201, 0.057, 0.000, 0.057, 0.000, deprecation.py:638(deprecated_argument_lookup)
# 2, 0.000, 0.000, 0.056, 0.028, dataset_ops.py:737(from_tensor_slices)
# 2, 0.000, 0.000, 0.056, 0.028, from_tensor_slices_op.py:24(from_tensor_slices)
# 2, 0.000, 0.000, 0.056, 0.028, from_tensor_slices_op.py:31(__init__)
# 4689, 0.055, 0.000, 0.055, 0.000, utils.py:36(<listcomp>)
# 9, 0.000, 0.000, 0.055, 0.006, 1795491062.py:3(init_kaiming_he)
# 4698, 0.032, 0.000, 0.054, 0.000, std.py:104(acquire)
# 2, 0.000, 0.000, 0.054, 0.027, structure.py:67(normalize_element)
# 9757, 0.024, 0.000, 0.054, 0.000, session.py:201(utcnow)
# 5634, 0.054, 0.000, 0.054, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_NewExecutor}
# 4689, 0.026, 0.000, 0.053, 0.000, tape.py:43(push_new_tape)
# 33, 0.001, 0.000, 0.052, 0.002, configurable.py:51(__init__)
# 45024, 0.052, 0.000, 0.052, 0.000, layer_utils.py:649(full_argspec)
# 11301, 0.051, 0.000, 0.051, 0.000, {built-in, method tensorflow.python.util._pywrap_utils.FlattenForData}
# 9757, 0.029, 0.000, 0.051, 0.000, hmac.py:128(_current)
# 22548, 0.051, 0.000, 0.051, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes}
# 9390, 0.042, 0.000, 0.050, 0.000, __init__.py:12(escape)
# 540/11, 0.003, 0.000, 0.050, 0.005, converter.py:306(visit)
# 29271, 0.049, 0.000, 0.049, 0.000, {method, 'copy' of '_hashlib.HASH' objects}
# 28134, 0.041, 0.000, 0.049, 0.000, backprop.py:646(<genexpr>)
# 5629, 0.036, 0.000, 0.048, 0.000, structure.py:214(<listcomp>)
# 66, 0.001, 0.000, 0.048, 0.001, base_comm.py:69(open)
# 25, 0.000, 0.000, 0.047, 0.002, optimizer.py:1067(add_variable_from_reference)
# 50652, 0.047, 0.000, 0.047, 0.000, activations.py:467(linear)
# 4689, 0.013, 0.000, 0.045, 0.000, distribution_strategy_context.py:57(_push_per_thread_mode)
# 25, 0.001, 0.000, 0.044, 0.002, optimizer.py:455(add_variable_from_reference)
# 21, 0.002, 0.000, 0.043, 0.002, op_def_library.py:751(_apply_op_helper)
# 6, 0.000, 0.000, 0.043, 0.007, file_io.py:197(__exit__)
# 6, 0.043, 0.007, 0.043, 0.007, file_io.py:223(close)
# 9798, 0.036, 0.000, 0.043, 0.000, threading.py:1066(_wait_for_tstate_lock)
# 4690, 0.014, 0.000, 0.042, 0.000, context.py:2761(_tmp_in_graph_mode)
# 78, 0.004, 0.000, 0.042, 0.001, traitlets.py:1325(__init__)
# 141099, 0.042, 0.000, 0.042, 0.000, {method, 'update' of 'dict' objects}
# 5640, 0.013, 0.000, 0.041, 0.000, config.py:1092(is_op_determinism_enabled)
# 4710, 0.024, 0.000, 0.041, 0.000, traitlets.py:2432(validate)
# 3, 0.000, 0.000, 0.040, 0.013, widget_float.py:23(__init__)
# 22654, 0.037, 0.000, 0.039, 0.000, tensor_shape.py:862(__len__)
# 14067, 0.039, 0.000, 0.039, 0.000, {method, 'copy' of 'numpy.ndarray' objects}
# 4689, 0.013, 0.000, 0.039, 0.000, distribution_strategy_context.py:61(_pop_per_thread_mode)
# 107752, 0.038, 0.000, 0.038, 0.000, {method, 'items' of 'dict' objects}
# 11268, 0.038, 0.000, 0.038, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_ContextSetExecutorForThread}
# 1, 0.000, 0.000, 0.038, 0.038, transpiler.py:163(create)
# 4689, 0.016, 0.000, 0.037, 0.000, tape.py:39(watched_variables)
# 1, 0.000, 0.000, 0.037, 0.037, image_ops_impl.py:375(random_flip_left_right)
# 1, 0.000, 0.000, 0.037, 0.037, image_ops_impl.py:485(_random_flip)
# 4689, 0.019, 0.000, 0.037, 0.000, backprop.py:891(_pop_tape)
# 28357, 0.036, 0.000, 0.036, 0.000, tensor_shape.py:807(_v2_behavior)
# 45024, 0.035, 0.000, 0.035, 0.000, device_context.py:17(enclosing_tpu_context)
# ...
# 4, 0.000, 0.000, 0.000, 0.000, control_flow_util.py:209(GetContainingXLAContext)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:1396(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, parser.py:196(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, codecs.py:186(__init__)
# 3, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python.client._pywrap_tf_session.AddControlInput}
# 2, 0.000, 0.000, 0.000, 0.000, context.py:1110(rewriter_bool)
# 5, 0.000, 0.000, 0.000, 0.000, ops.py:3425(seed)
# 4, 0.000, 0.000, 0.000, 0.000, func_graph.py:108(<genexpr>)
# 1, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:798(enable)
# 3, 0.000, 0.000, 0.000, 0.000, <frozen, importlib._bootstrap>:736(find_spec)
# 3, 0.000, 0.000, 0.000, 0.000, formatters.py:271(_get_type)
# 1, 0.000, 0.000, 0.000, 0.000, tf_inspect.py:292(<listcomp>)
# 2, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:598(forward)
# 4, 0.000, 0.000, 0.000, 0.000, ast3.py:418(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, reaching_fndefs.py:63(__add__)
# 1, 0.000, 0.000, 0.000, 0.000, monitoring.py:480(__enter__)
# 5, 0.000, 0.000, 0.000, 0.000, dataset_ops.py:4519(_inputs)
# 1, 0.000, 0.000, 0.000, 0.000, transpiler.py:146(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:809(show_results)
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:321(Event)
# 4, 0.000, 0.000, 0.000, 0.000, ops.py:3430(seed)
# 5, 0.000, 0.000, 0.000, 0.000, structured_function.py:283(output_structure)
# 36, 0.000, 0.000, 0.000, 0.000, {method, 'getrandbits' of '_random.Random' objects}
# 4, 0.000, 0.000, 0.000, 0.000, ast3.py:424(<listcomp>)
# 3, 0.000, 0.000, 0.000, 0.000, function_base.py:1452(_interp_dispatcher)
# 4, 0.000, 0.000, 0.000, 0.000, default_types.py:465(__init__)
# 5, 0.000, 0.000, 0.000, 0.000, ops.py:4917(control_inputs)
# 13, 0.000, 0.000, 0.000, 0.000, {method, 'items' of 'mappingproxy' objects}
# 4, 0.000, 0.000, 0.000, 0.000, <frozen, importlib._bootstrap_external>:1031(get_filename)
# 3, 0.000, 0.000, 0.000, 0.000, sre_parse.py:287(tell)
# 1, 0.000, 0.000, 0.000, 0.000, tempfile.py:476(func_wrapper)
# 1, 0.000, 0.000, 0.000, 0.000, six.py:598(iterkeys)
# 1, 0.000, 0.000, 0.000, 0.000, gradients_util.py:1032(PossibleTapeGradientTypes)
# 1, 0.000, 0.000, 0.000, 0.000, quarantine.py:364(defun_with_attributes)
# 2, 0.000, 0.000, 0.000, 0.000, <string>:1(<lambda>)
# 3, 0.000, 0.000, 0.000, 0.000, sre_parse.py:250(match)
# 1, 0.000, 0.000, 0.000, 0.000, tempfile.py:419(__init__)
# 3, 0.000, 0.000, 0.000, 0.000, call_trees.py:66(add_arg)
# 4, 0.000, 0.000, 0.000, 0.000, function_spec.py:366(<genexpr>)
# 1, 0.000, 0.000, 0.000, 0.000, tracing_compiler.py:279(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, transformer.py:51(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, naming.py:23(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, control_flow_util_v2.py:326(get_op_and_outputs)
# 1, 0.000, 0.000, 0.000, 0.000, tempfile.py:448(close)
# 1, 0.000, 0.000, 0.000, 0.000, getlimits.py:672(max)
# 2, 0.000, 0.000, 0.000, 0.000, function_cache.py:43(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'extend' of 'google.protobuf.pyext._message.RepeatedCompositeContainer' objects}
# 3, 0.000, 0.000, 0.000, 0.000, inspect.py:286(isbuiltin)
# 3, 0.000, 0.000, 0.000, 0.000, func_graph.py:1314(<listcomp>)
# 2, 0.000, 0.000, 0.000, 0.000, function_spec.py:184(<dictcomp>)
# 9, 0.000, 0.000, 0.000, 0.000, {built-in, method _weakref.proxy}
# 41, 0.000, 0.000, 0.000, 0.000, {built-in, method builtins.ord}
# 3, 0.000, 0.000, 0.000, 0.000, cfg.py:658(_enter_lexical_scope)
# 4, 0.000, 0.000, 0.000, 0.000, ops.py:3469(_set_control_flow_context)
# 4, 0.000, 0.000, 0.000, 0.000, tensor_shape.py:881(<genexpr>)
# 4, 0.000, 0.000, 0.000, 0.000, tensor_spec.py:92(name)
# 1, 0.000, 0.000, 0.000, 0.000, func_graph.py:137(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:382(_validate_inputs)
# 2/1, 0.000, 0.000, 0.000, 0.000, activity.py:131(referenced)
# 1, 0.000, 0.000, 0.000, 0.000, functions.py:37(_function_scope_options)
# 1, 0.000, 0.000, 0.000, 0.000, sre_parse.py:928(fix_flags)
# 2, 0.000, 0.000, 0.000, 0.000, type_spec.py:189(<genexpr>)
# 3, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:247(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, sre_parse.py:76(__init__)
# 2, 0.000, 0.000, 0.000, 0.000, ast.py:762(get_precedence)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python.client._pywrap_tf_session.TF_FunctionSetAttrValueProto}
# 1, 0.000, 0.000, 0.000, 0.000, threading.py:1162(daemon)
# 1, 0.000, 0.000, 0.000, 0.000, traitlets.py:3387(subclass_init)
# 1, 0.000, 0.000, 0.000, 0.000, zmqshell.py:69(_default_thread_local)
# 2, 0.000, 0.000, 0.000, 0.000, ops.py:5419(_colocation_stack)
# 4, 0.000, 0.000, 0.000, 0.000, type_spec.py:510(__tf_tracing_type__)
# 2, 0.000, 0.000, 0.000, 0.000, traceable_stack.py:101(pop_obj)
# 4, 0.000, 0.000, 0.000, 0.000, object_identity.py:35(unwrapped)
# 1, 0.000, 0.000, 0.000, 0.000, context.py:233(get_context)
# 1, 0.000, 0.000, 0.000, 0.000, func_graph.py:1045(deferred_external_captures)
# 4, 0.000, 0.000, 0.000, 0.000, function_type.py:132(captures)
# 1, 0.000, 0.000, 0.000, 0.000, api.py:651(convert)
# 2, 0.000, 0.000, 0.000, 0.000, contextlib.py:688(__init__)
# 3, 0.000, 0.000, 0.000, 0.000, func_graph.py:654(<listcomp>)
# 3, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:179(__init__)
# 3, 0.000, 0.000, 0.000, 0.000, variable_scope.py:1193(use_resource)
# 5, 0.000, 0.000, 0.000, 0.000, {method, 'WhichOneof' of 'google.protobuf.pyext._message.CMessage' objects}
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:272(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:123(Semaphore)
# 4, 0.000, 0.000, 0.000, 0.000, device_spec.py:266(job)
# 4, 0.000, 0.000, 0.000, 0.000, device_spec.py:274(task)
# 3, 0.000, 0.000, 0.000, 0.000, func_graph.py:1053(<listcomp>)
# 5, 0.000, 0.000, 0.000, 0.000, {method, 'find' of 'str' objects}
# 20, 0.000, 0.000, 0.000, 0.000, {method, 'isalnum' of 'str' objects}
# 2, 0.000, 0.000, 0.000, 0.000, origin_info.py:158(__init__)
# 2, 0.000, 0.000, 0.000, 0.000, sre_compile.py:619(isstring)
# 1, 0.000, 0.000, 0.000, 0.000, {method, '__enter__' of '_io._IOBase' objects}
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:258(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, api.py:196(get_extra_locals)
# 1, 0.000, 0.000, 0.000, 0.000, six.py:190(find_spec)
# 1, 0.000, 0.000, 0.000, 0.000, __init__.py:227(_releaseLock)
# 4, 0.000, 0.000, 0.000, 0.000, device_spec.py:282(device_index)
# 2, 0.000, 0.000, 0.000, 0.000, save_context.py:42(in_save_context)
# 12, 0.000, 0.000, 0.000, 0.000, {method, '__enter__' of '_thread.lock' objects}
# 3, 0.000, 0.000, 0.000, 0.000, {built-in, method _imp.is_frozen}
# 3, 0.000, 0.000, 0.000, 0.000, <frozen, importlib._bootstrap>:406(has_location)
# 3, 0.000, 0.000, 0.000, 0.000, <frozen, importlib._bootstrap_external>:841(create_module)
# 4, 0.000, 0.000, 0.000, 0.000, device_spec.py:270(replica)
# 4, 0.000, 0.000, 0.000, 0.000, device_spec.py:278(device_type)
# 18, 0.000, 0.000, 0.000, 0.000, {method, 'index' of 'list' objects}
# 1, 0.000, 0.000, 0.000, 0.000, function_wrappers.py:79(__exit__)
# 2, 0.000, 0.000, 0.000, 0.000, sre_compile.py:477(_get_iscased)
# 2, 0.000, 0.000, 0.000, 0.000, sre_parse.py:82(groups)
# 3, 0.000, 0.000, 0.000, 0.000, type_check.py:206(_is_type_dispatcher)
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:211(<dictcomp>)
# 3, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:1785(graph)
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:90(_make_methods)
# 1, 0.000, 0.000, 0.000, 0.000, __init__.py:1675(getEffectiveLevel)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_MonitoringCounterCellIncrementBy}
# 2, 0.000, 0.000, 0.000, 0.000, type_spec.py:179(<genexpr>)
# 2, 0.000, 0.000, 0.000, 0.000, func_graph.py:603(outer_graph)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method FromString}
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method nt._getfullpathname}
# 4, 0.000, 0.000, 0.000, 0.000, {method, 'extend' of 'bytearray' objects}
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:683(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:899(<dictcomp>)
# 3, 0.000, 0.000, 0.000, 0.000, std.py:165(colour)
# 1, 0.000, 0.000, 0.000, 0.000, six.py:194(find_spec)
# 1, 0.000, 0.000, 0.000, 0.000, device_spec.py:335(<listcomp>)
# 3, 0.000, 0.000, 0.000, 0.000, func_graph.py:169(captures)
# 3, 0.000, 0.000, 0.000, 0.000, jsonutil.py:52(encode_images)
# 2, 0.000, 0.000, 0.000, 0.000, type_spec.py:161(<genexpr>)
# 3, 0.000, 0.000, 0.000, 0.000, function_spec.py:297(is_method)
# 1, 0.000, 0.000, 0.000, 0.000, type_dispatch.py:38(__init__)
# 2, 0.000, 0.000, 0.000, 0.000, {built-in, method _imp._fix_co_filename}
# 2, 0.000, 0.000, 0.000, 0.000, functions.py:30(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, traitlets.py:2510(validate)
# 2, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python.client._pywrap_tf_session.TF_OperationDevice}
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:390(validate_inputs_with_signature)
# 4, 0.000, 0.000, 0.000, 0.000, {method, 'rsplit' of 'str' objects}
# 1, 0.000, 0.000, 0.000, 0.000, function_wrappers.py:70(__enter__)
# 1, 0.000, 0.000, 0.000, 0.000, std.py:100(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:805(disable)
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:184(RLock)
# 1, 0.000, 0.000, 0.000, 0.000, nest.py:331(is_nested_or_composite)
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'write' of '_io.TextIOWrapper' objects}
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:159(Lock)
# 1, 0.000, 0.000, 0.000, 0.000, __autograph_generated_file6jojo59y.py:4(inner_factory)
# 1, 0.000, 0.000, 0.000, 0.000, __autograph_generated_file6jojo59y.py:2(outer_factory)
# 2, 0.000, 0.000, 0.000, 0.000, sre_parse.py:169(__setitem__)
# 15, 0.000, 0.000, 0.000, 0.000, {method, 'values' of 'collections.OrderedDict' objects}
# 1, 0.000, 0.000, 0.000, 0.000, liveness.py:53(lamba_check)
# 1, 0.000, 0.000, 0.000, 0.000, transpiler.py:247(get_transformed_name)
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:261(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, synchronize.py:142(BoundedSemaphore)
# 2, 0.000, 0.000, 0.000, 0.000, functools.py:420(_unwrap_partial)
# 1, 0.000, 0.000, 0.000, 0.000, trace_type_builder.py:42(add_listener)
# 8, 0.000, 0.000, 0.000, 0.000, {method, 'decode' of 'bytes' objects}
# 8, 0.000, 0.000, 0.000, 0.000, {method, 'strip' of 'str' objects}
# 1, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:597(__init__)
# 2, 0.000, 0.000, 0.000, 0.000, trace_type_builder.py:82(deletion_observer)
# 2, 0.000, 0.000, 0.000, 0.000, tensor_spec.py:117(_serialize)
# 2, 0.000, 0.000, 0.000, 0.000, tensor_spec.py:214(value_type)
# 1, 0.000, 0.000, 0.000, 0.000, op_def_library.py:181(_MakeBool)
# 2, 0.000, 0.000, 0.000, 0.000, from_tensor_slices_op.py:56(element_spec)
# 1, 0.000, 0.000, 0.000, 0.000, converter.py:239(__init__)
# 2, 0.000, 0.000, 0.000, 0.000, contextlib.py:694(__exit__)
# 1, 0.000, 0.000, 0.000, 0.000, threading.py:757(_newname)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TF_IsMlirBridgeEnabled}
# 1, 0.000, 0.000, 0.000, 0.000, context.py:1475(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, ops.py:5323(prevent_fetching)
# 16, 0.000, 0.000, 0.000, 0.000, {method, 'bit_length' of 'int' objects}
# 2, 0.000, 0.000, 0.000, 0.000, contextlib.py:691(__enter__)
# 1, 0.000, 0.000, 0.000, 0.000, copyreg.py:94(__newobj__)
# 1, 0.000, 0.000, 0.000, 0.000, data_structures.py:807(<dictcomp>)
# 2, 0.000, 0.000, 0.000, 0.000, structured_function.py:305(function)
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'MergeFrom' of 'google.protobuf.pyext._message.CMessage' objects}
# 2, 0.000, 0.000, 0.000, 0.000, {method, 'tobytes' of 'numpy.ndarray' objects}
# 3, 0.000, 0.000, 0.000, 0.000, {method, 'difference' of 'set' objects}
# 9, 0.000, 0.000, 0.000, 0.000, {built-in, method builtins.abs}
# 2, 0.000, 0.000, 0.000, 0.000, function_spec.py:224(default_values)
# 2, 0.000, 0.000, 0.000, 0.000, {built-in, method atexit.register}
# 1, 0.000, 0.000, 0.000, 0.000, call_trees.py:40(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, tempfile.py:284(gettempdir)
# 2, 0.000, 0.000, 0.000, 0.000, dataset_ops.py:4508(_inputs)
# 1, 0.000, 0.000, 0.000, 0.000, __autograph_generated_file6jojo59y.py:2(<module>)
# 1, 0.000, 0.000, 0.000, 0.000, threading.py:1147(daemon)
# 1, 0.000, 0.000, 0.000, 0.000, tempfile.py:229(_get_candidate_names)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TFE_Py_TapeSetPossibleGradientTypes}
# 1, 0.000, 0.000, 0.000, 0.000, tf_stack.py:87(get_effective_source_map)
# 4, 0.000, 0.000, 0.000, 0.000, {built-in, method sys.audit}
# 1, 0.000, 0.000, 0.000, 0.000, transpiler.py:198(<genexpr>)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method tensorflow.python._pywrap_tfe.TF_ListPluggablePhysicalDevices}
# 1, 0.000, 0.000, 0.000, 0.000, monitoring.py:157(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, structured_function.py:44(_should_pack)
# 1, 0.000, 0.000, 0.000, 0.000, type_dispatch.py:99(_cache_dispatch)
# 1, 0.000, 0.000, 0.000, 0.000, inspect.py:511(_is_wrapper)
# 1, 0.000, 0.000, 0.000, 0.000, control_flow_util.py:46(EnableControlFlowV2)
# 1, 0.000, 0.000, 0.000, 0.000, context.py:197(get_start_method)
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:449(<dictcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:1401(<genexpr>)
# 3, 0.000, 0.000, 0.000, 0.000, {method, 'setter' of 'property' objects}
# 3, 0.000, 0.000, 0.000, 0.000, {method, 'to_bytes' of 'int' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method _imp.extension_suffixes}
# 1, 0.000, 0.000, 0.000, 0.000, util.py:48(debug)
# 1, 0.000, 0.000, 0.000, 0.000, cond_v2.py:1265(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, context.py:172(executor_type)
# 1, 0.000, 0.000, 0.000, 0.000, monitoring.py:472(__init__)
# 1, 0.000, 0.000, 0.000, 0.000, func_graph.py:1048(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:1795(structured_input_signature)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:1950(<listcomp>)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:2296(__init__)
# 4, 0.000, 0.000, 0.000, 0.000, {method, 'isdigit' of 'str' objects}
# 1, 0.000, 0.000, 0.000, 0.000, __init__.py:1276(disable)
# 1, 0.000, 0.000, 0.000, 0.000, _compat.py:51(find_spec)
# 1, 0.000, 0.000, 0.000, 0.000, structured_function.py:65(_should_unpack)
# 1, 0.000, 0.000, 0.000, 0.000, tracing_compiler.py:142(function_spec)
# 1, 0.000, 0.000, 0.000, 0.000, monomorphic_function.py:2299(release)
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method _sre.compile}
# 1, 0.000, 0.000, 0.000, 0.000, api.py:219(get_caching_key)
# 1, 0.000, 0.000, 0.000, 0.000, image_ops_impl.py:514(<lambda>)
# 1, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:646(items)
# 1, 0.000, 0.000, 0.000, 0.000, traitlets.py:2383(subclass_init)
# 1, 0.000, 0.000, 0.000, 0.000, dataset_ops.py:5573(_transformation_name)
# 1, 0.000, 0.000, 0.000, 0.000, polymorphic_function.py:441(functions_run_eagerly)
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:329(vararg_name)
# 7, 0.000, 0.000, 0.000, 0.000, {method, 'items' of 'collections.OrderedDict' objects}
# 4, 0.000, 0.000, 0.000, 0.000, {method, 'discard' of 'set' objects}
# 2, 0.000, 0.000, 0.000, 0.000, {built-in, method sys.settrace}
# 1, 0.000, 0.000, 0.000, 0.000, traitlets.py:2679(subclass_init)
# 1, 0.000, 0.000, 0.000, 0.000, context.py:168(executor_type)
# 1, 0.000, 0.000, 0.000, 0.000, tf_stack.py:110(get_filtered_filenames)
# 1, 0.000, 0.000, 0.000, 0.000, function_spec.py:317(is_pure)
# 4, 0.000, 0.000, 0.000, 0.000, memory_profiler.py:1167(<genexpr>)
# 2, 0.000, 0.000, 0.000, 0.000, {method, 'lstrip' of 'str' objects}
# 4, 0.000, 0.000, 0.000, 0.000, {method, 'isalpha' of 'str' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'intersection' of 'set' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'mro' of 'type' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'close' of '_io.TextIOWrapper' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'insert' of 'list' objects}
# 2, 0.000, 0.000, 0.000, 0.000, {method, 'partition' of 'str' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method sys.getrecursionlimit}
# 1, 0.000, 0.000, 0.000, 0.000, {method, 'disable' of '_lsprof.Profiler' objects}
# 1, 0.000, 0.000, 0.000, 0.000, {built-in, method sys.gettrace}

# %%
# Using 3 decimal places in output display
pd.set_option("display.precision", 4)

# Preventing wrapping repr(DataFrame) across additional lines
pd.set_option("display.expand_frame_repr", False)

# Setting max rows displayed in output to 25
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_csv('./logs/cifar10.csv',skipinitialspace=True)
# Displaying Column names
df.columns
# Renaming pandas col
df.rename(columns={'percall.1':'module_name'},inplace=True)
df = df.drop(['filename:lineno(function)'],axis=1)
df=df[:-1] # Deleting last row as part of data cleaning
df['total_num_calls']=""
df['total_num_calls']=df.index # Resetting index
df[['total_num_calls', 'num_recursion']] = df['total_num_calls'].str.split("/", n=1, expand=True)
# Changing the data type
convert_dict = {'module_name': str, 
                'total_num_calls': int,
                'tottime':float   ,
                'cumtime':float,
                'ncalls' :float,
                'percall':float                
                               } 
df = df.astype(convert_dict)

# %%
# Deriving column total time = Time taken per call * Total num of calls
df['total_time']=df['percall'] * df['total_num_calls']
df['total_time']=df['total_time'].apply(np.ceil)
# Converting to seconds
df['total_time'] = df['total_time'] / 1000.0

# %%
# Create extra copy for safety 
df1=df
# Extracting only module name
df1['module_name']= df['module_name'].str.extract('(\\w+.py)')
# Dropping if any NaN exist
df1=df1.dropna(subset=['module_name'])
# Removing extra White Space
df1['module_name']=df1['module_name'].str.strip()
df2=df1
# Adding same modules' total time
df2 = df1.groupby(["module_name"])["total_time"].sum()

# %%
df2.head()
# Out:
# module_name
# 1201675695.py        7.820
# 1206929776.py    76524.052
# 1795491062.py        0.001
# 3051841859.py    10265.720
# 414650165.py         0.000
# Name: total_time, dtype: float64

# %%
df2 = pd.DataFrame(df2)
df2=df2.reset_index()
df2 = df2[df2['total_time']>1]
df2 = df2.sort_values(by='total_time',ascending=False)
df2
# Out:
#                           module_name  total_time
# 232                traceback_utils.py  5.9633e+06
# 87                        dispatch.py  2.8818e+06
# 30                        backprop.py  1.4430e+06
# 154                       math_ops.py  4.9580e+05
# 35                      base_layer.py  3.9217e+05
# 90                  distribute_lib.py  2.6739e+05
# 120                     gen_nn_ops.py  2.4683e+05
# 59                         context.py  1.9451e+05
# 162                        nn_grad.py  1.9438e+05
# 174                      optimizer.py  1.8802e+05
# 164                         nn_ops.py  1.6083e+05
# 161                           nest.py  1.5110e+05
# 119                   gen_math_ops.py  1.4656e+05
# 194          resource_variable_ops.py  1.2951e+05
# 173                            ops.py  1.2634e+05
# 234                       training.py  1.2547e+05
# 34                       base_conv.py  1.0713e+05
# 19                             api.py  9.1910e+04
# 198                            sgd.py  8.5609e+04
# 1                       1206929776.py  7.6524e+04
# 229                          trace.py  7.4635e+04
# 60                      contextlib.py  7.3753e+04
# 214                   tensor_shape.py  7.0946e+04
# 251                      variables.py  4.8753e+04
# 38             batch_normalization.py  4.3768e+04
# 92                          dtypes.py  4.2141e+04
# 5                       4239356372.py  2.8854e+04
# 133                imperative_grad.py  2.3576e+04
# 13                             abc.py  2.1119e+04
# 122      gen_resource_variable_ops.py  1.4928e+04
# 64               control_flow_util.py  1.2206e+04
# 200                     smart_cond.py  1.2162e+04
# 163                        nn_impl.py  1.2017e+04
# 3                       3051841859.py  1.0266e+04
# 91   distribution_strategy_context.py  6.7421e+03
# 57                     constant_op.py  3.6739e+03
# 156             merge_call_interim.py  3.6171e+03
# 210                           tape.py  3.5043e+03
# 137                     input_spec.py  3.3270e+03
# 236                      traitlets.py  2.0492e+03
# 220                   tf_decorator.py  1.7893e+03
# 50       composite_tensor_gradient.py  1.7283e+03
# 48                          compat.py  1.3695e+03
# 213     tensor_conversion_registry.py  1.0868e+03
# 249                 variable_scope.py  1.0864e+03
# 192                       registry.py  1.0115e+03
# 36                base_layer_utils.py  1.0071e+03
# 31                   backprop_util.py  9.5873e+02
# 37                  base_pooling2d.py  7.7241e+02
# 114                  gen_array_ops.py  6.4359e+02
# 16                          ag_ctx.py  6.3013e+02
# 8                 _collections_abc.py  5.0227e+02
# 216                    tensor_util.py  4.2933e+02
# 75                 data_structures.py  3.6941e+02
# 145                    layer_utils.py  3.6512e+02
# 29                         backend.py  3.1350e+02
# 225                       tf_utils.py  3.0556e+02
# 112                      functools.py  3.0400e+02
# 74                 custom_gradient.py  3.0203e+02
# 253                         widget.py  2.7361e+02
# 27               autocast_variable.py  2.6962e+02
# 20                       array_ops.py  2.4850e+02
# 204                            std.py  2.2049e+02
# 165                       notebook.py  2.1067e+02
# 138                        inspect.py  2.0977e+02
# 197                        session.py  2.0371e+02
# 153                      math_grad.py  1.3422e+02
# 7                         __init__.py  1.2815e+02
# 247                          utils.py  1.1126e+02
# 93                         encoder.py  8.8830e+01
# 142                   iterator_ops.py  8.1137e+01
# 47                            comm.py  7.6963e+01
# 33                       base_comm.py  7.6710e+01
# 140                       iostream.py  5.8216e+01
# 205                      structure.py  4.6386e+01
# 252                        weakref.py  3.5935e+01
# 63                control_flow_ops.py  2.5083e+01
# 96                         execute.py  2.1921e+01
# 116                gen_dataset_ops.py  2.0702e+01
# 127           global_max_pooling2d.py  1.9856e+01
# 215                    tensor_spec.py  1.7816e+01
# 99                           flags.py  1.6949e+01
# 201                         socket.py  1.6599e+01
# 155                memory_profiler.py  1.5640e+01
# 80                           dense.py  1.3886e+01
# 167                        numeric.py  7.8520e+00
# 0                       1201675695.py  7.8200e+00
# 81                     deprecation.py  6.8170e+00
# 143                       jsonutil.py  6.5380e+00
# 221                     tf_inspect.py  6.4640e+00
# 131                           hmac.py  5.2610e+00
# 97                        executor.py  3.6370e+00
# 179                         policy.py  2.8850e+00
# 14                     activations.py  2.3810e+00
# 226                      threading.py  1.6320e+00
# 83                  device_context.py  1.5760e+00
# 67                      conv_utils.py  1.3060e+00
# 183                       profiler.py  1.1730e+00
# 94                            enum.py  1.1270e+00

# %%
# %matplotlib inline
# Plotting Graphs
top20 = df2.head(20)
g=sns.catplot(x='module_name', y='total_time', data=top20, kind='bar')
g.set_xticklabels(rotation=90)
g.set_xlabels("function called")
g.set_ylabels("Total_Time in seconds")
plt.title('Total Time Taken in seconds', weight='bold', fontsize=16)
plt.show()

# %%
# Selecting specific modules used in model building

df3 =df2[df2['module_name'].str.contains("grad") | 
        df2['module_name'].str.contains('conv')|
        df2['module_name'].str.contains('backprop')|
        df2['module_name'].str.contains('normal') |
        df2['module_name'].str.contains('tape') |
        df2['module_name'].str.contains('array') |
        df2['module_name'].str.contains('tensor') |
        df2['module_name'].str.contains('deprecat') |
        df2['module_name'].str.contains('iter') |
        df2['module_name'].str.contains('pool') |
        df2['module_name'].str.contains('layer') |
        df2['module_name'].str.contains('ops') |
        df2['module_name'].str.contains('custom') ]

# %%
# %matplotlib inline
# Plotting
top25_custom= df3[:26]
g=sns.catplot(x='module_name', y='total_time', data=top25_custom, kind='bar')
g.set_xticklabels(rotation=90)
g.set_xlabels("function called")
g.set_ylabels("Total_Time in seconds")
plt.title('Total Time Taken in seconds', weight='bold', fontsize=16)
plt.show()

# %%
# !pip install snakeviz
# Out:
# Requirement already satisfied: snakeviz in c:\users\manas\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: tornado>=2.0 in c:\users\manas\anaconda3\lib\site-packages (from snakeviz) (6.1)

# %%
# Visualising using SnakeViz
# %load_ext snakeviz
# %snakeviz fit()
# Out:
# ERROR: Could not find file C:\Users\MANAS\AppData\Local\Temp\ipykernel_8228\1201675695.py
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 1, lr:0.267,Train Loss: 0.677,Train Accuracy: 76.910, Test Loss: 0.837, Test Accuracy: 73.060,Time Taken: 10191.76
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 2, lr:0.133,Train Loss: 0.606,Train Accuracy: 79.260, Test Loss: 0.537, Test Accuracy: 81.410,Time Taken: 12751.49
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 3, lr:0.000,Train Loss: 0.555,Train Accuracy: 81.082, Test Loss: 0.580, Test Accuracy: 80.900,Time Taken: 15340.80
#
# *** Profile stats marshalled to file 'C:\\Users\\MANAS\\AppData\\Local\\Temp\\tmp7a1pwbx9'.
# Embedding SnakeViz in this document...
# <iframe id='snakeviz-0cd309d1-bf50-11ed-abd9-d8bbc11c22cd' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-0cd309d1-bf50-11ed-abd9-d8bbc11c22cd").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/C%3A%5CUsers%5CMANAS%5CAppData%5CLocal%5CTemp%5Ctmp7a1pwbx9")</script>

# %%
# !pip install memory_profiler
# %load_ext memory_profiler
# Out:
# Requirement already satisfied: memory_profiler in c:\users\manas\anaconda3\lib\site-packages (0.61.0)
# Requirement already satisfied: psutil in c:\users\manas\anaconda3\lib\site-packages (from memory_profiler) (5.9.0)

# %%
# %mprun -T mem_results.txt -f fit fit()
# Out:
# ERROR: Could not find file C:\Users\MANAS\AppData\Local\Temp\ipykernel_8228\1201675695.py
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 1, lr:0.267,Train Loss: 0.515,Train Accuracy: 82.446, Test Loss: 0.612, Test Accuracy: 80.640,Time Taken: 17932.74
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 2, lr:0.133,Train Loss: 0.486,Train Accuracy: 83.574, Test Loss: 0.552, Test Accuracy: 81.860,Time Taken: 20737.16
#   0%|          | 0/1563 [00:00<?, ?it/s]
# Epoch 3, lr:0.000,Train Loss: 0.446,Train Accuracy: 84.832, Test Loss: 0.481, Test Accuracy: 84.280,Time Taken: 23715.55
#
#
# *** Profile printout saved to text file mem_results.txt.

# %%
with open('mem_results.txt', 'r') as f:
    print(f.read())
# Out:
# Filename: C:\Users\MANAS\anaconda3\lib\site-packages\memory_profiler.py
#
# Line #    Mem usage    Increment  Occurences   Line Contents
# ============================================================
#   1140   1694.9 MiB   1694.9 MiB           1               def wrapper(*args, **kwargs):
#   1141   1694.9 MiB      0.0 MiB           1                   prof = get_prof()
#   1142   1706.7 MiB     11.8 MiB           1                   val = prof(func)(*args, **kwargs)
#   1143   1706.7 MiB      0.0 MiB           1                   show_results_bound(prof)
#   1144   1706.7 MiB      0.0 MiB           1                   return val
